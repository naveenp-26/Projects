# %%
import requests

url = 'https://notes.ayushsharma.in/technology'

data = requests.get(url)

print(data.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" data-bs-theme="dark">
# <head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#
# 	<title>ayush sharma (づ｡◕‿‿◕｡)づ - Technology</title>
# 	<meta name="description" content="Technology" />
#
# 	<link rel="canonical" href="https://www.ayush.nz/technology">
#
# 	<!-- RSS -->
# 	<link rel="alternate" type="application/rss+xml" title="ayush sharma (づ｡◕‿‿◕｡)づ" href="https://www.ayush.nz/feed.xml">
#
# 	<!-- Favicons -->
# 	<link rel="apple-touch-icon" sizes="180x180"
# 		href="https://www.ayush.nz/static/images/meta/favicon/apple-touch-icon.png">
# 	<link rel="icon" type="image/png" sizes="32x32"
# 		href="https://www.ayush.nz/static/images/meta/favicon/favicon-32x32.png">
# 	<link rel="icon" type="image/png" sizes="16x16"
# 		href="https://www.ayush.nz/static/images/meta/favicon/favicon-16x16.png">
# 	<link rel="manifest"
# 		href="https://www.ayush.nz/static/images/meta/favicon/site.webmanifest">
# 	<link rel="mask-icon"
# 		href="https://www.ayush.nz/static/images/meta/favicon/safari-pinned-tab.svg"
# 		color="#5bbad5">
# 	<link rel="shortcut icon"
# 		href="https://www.ayush.nz/static/images/meta/favicon/favicon.ico">
# 	<meta name="msapplication-TileColor" content="#da532c">
# 	<meta name="msapplication-config"
# 		content="https://www.ayush.nz/static/images/meta/favicon/browserconfig.xml">
# 	<meta name="theme-color" content="#ffffff">
#
# 	<meta name="apple-mobile-web-app-title" content="Technology
# 		- ayush sharma (づ｡◕‿‿◕｡)づ">
# 	<meta name="application-name" content="Technology
# 		- ayush sharma (づ｡◕‿‿◕｡)づ">
#
# 	<!-- CSS -->
# 	<link rel="stylesheet" href="https://www.ayush.nz/css/simple.css">
# 	<link rel="stylesheet" href="https://www.ayush.nz/css/my.css">
#
# 	<!-- OG tags -->
# 	<meta property="og:site_name" content="ayush sharma (づ｡◕‿‿◕｡)づ" />
# 	<meta property=“og:title” content=“Technology - ayush sharma (づ｡◕‿‿◕｡)づ" />
# 	<meta property="og:description"
# 		content="" />
# 	<meta property="og:url"
# 		content="https://www.ayush.nz/technology" />
# 	<meta property="og:type" content="article" />
#
#
# </head>
#
# <header>
#   <nav>
# 	<a href="/" title="Home">Home 🏠</a>
# <a href="/life-stuff" title="Life stuff">Life stuff ☕</a>
# <a href="/technology" title="Technology">Technology 🛸</a>
# <a href="/video-games" title="Video Games">Video Games 🕹️</a>
# <a href="/books" title="Books">Books 📖</a>
# <a href="/photos" title="Photos">Photos 📖</a>
# <a href="/about" title="About Me">About Me 🙌</a>
# <a href="/feed.xml" title="Subscribe!">Subscribe! 🔔</a>
# </nav>
# </header>
#
# <body>
#   <main>
#     <h1>Technology<span class="xs"> (⊙＿⊙')</span></h1>
#
# <div class="article-link">
#     <p>
#         <a href="/2022/11/consuming-apis-responsibly" title="Consuming APIs responsibly">Consuming APIs responsibly</a><span class="muted"> / Nov 2022</span>
#         <div class="excerpt">
#             Or: Etiquette and table manners for pinging other people's servers.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2022-11-21-consuming-apis-responsibly.png" alt="Banner image for Consuming APIs responsibly" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2022/02/creating-article-series-posts-navigation-jekyll" title="Create a series of posts with navigation in Jekyll">Create a series of posts with navigation in Jekyll</a><span class="muted"> / Feb 2022</span>
#         <div class="excerpt">
#             Add Jekyll posts into a series with series navigation.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2022-02-18-creating-article-series-posts-navigation-jekyll-series-navigation.png" alt="Banner image for Create a series of posts with navigation in Jekyll" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2022/01/practical-light-dark-mode-jekyll-bootstrap5" title="A practical guide to light and dark mode in Bootstrap 5 and Jekyll">A practical guide to light and dark mode in Bootstrap 5 and Jekyll</a><span class="muted"> / Jan 2022</span>
#         <div class="excerpt">
#             Implementing light and dark mode on your Bootstrap 5 + Jekyll website.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2022-01-25-practical-light-dark-mode-jekyll-bootstrap5-banner.jpg" alt="Banner image for A practical guide to light and dark mode in Bootstrap 5 and Jekyll" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2022/01/nemo-file-manager-ubuntu-20.04-linux-nautilus-alternative" title="Nemo - The Ubuntu file manager you didn’t know you needed">Nemo - The Ubuntu file manager you didn’t know you needed</a><span class="muted"> / Jan 2022</span>
#         <div class="excerpt">
#             Celebrate 2022 with a shiny new file manager for Ubuntu!
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2022-01-25-nemo-file-manager-ubuntu-20.04-linux-nautilus-alternative-home.jpg" alt="Banner image for Nemo - The Ubuntu file manager you didn’t know you needed" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2022/01/announcing-fediverse-to" title="Announcing Fediverse.to!">Announcing Fediverse.to!</a><span class="muted"> / Jan 2022</span>
#         <div class="excerpt">
#             I've been working on a search engine for Fediverse instances!
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2022-01-01-announcing-fediverse-to.png" alt="Banner image for Announcing Fediverse.to!" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/11/easy-pretty-url-redirects-with-jekyll-and-netlify" title="Easy pretty URL redirects with Jekyll and Netlify">Easy pretty URL redirects with Jekyll and Netlify</a><span class="muted"> / Nov 2021</span>
#         <div class="excerpt">
#             Combine Jekyll and Netlify to create pretty URL redirects as easy as 1-2-3.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-11-16-easy-pretty-url-redirects-with-jekyll-and-netlify.jpg" alt="Banner image for Easy pretty URL redirects with Jekyll and Netlify" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/11/linking-jekyll-pages-back-to-their-git-source-code" title="Linking Jekyll pages back to their Git source code">Linking Jekyll pages back to their Git source code</a><span class="muted"> / Nov 2021</span>
#         <div class="excerpt">
#             Add a link back to the public Git hosting link for any static Jekyll blog.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-11-16-linking-jekyll-pages-back-to-their-git-source-code.jpg" alt="Banner image for Linking Jekyll pages back to their Git source code" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/11/optimising-jpg-and-png-images-for-a-jekyll-blog" title="Optimising JPG and PNG images for a Jekyll website">Optimising JPG and PNG images for a Jekyll website</a><span class="muted"> / Nov 2021</span>
#         <div class="excerpt">
#             Use CLI tools to generate resized and optimised thumbnails for articles header images.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-11-16-optimising-jpg-and-png-images-for-a-jekyll-blog.jpg" alt="Banner image for Optimising JPG and PNG images for a Jekyll website" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/11/using-lunr-js-to-create-client-side-website-search-index" title="Quick and easy client-side JavaScript search with Lunr.js">Quick and easy client-side JavaScript search with Lunr.js</a><span class="muted"> / Nov 2021</span>
#         <div class="excerpt">
#             Display search results from any JSON data object in the browser using Lunr.js.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-11-01-using-lunr-js-to-create-client-side-website-search-index-banner.svg" alt="Banner image for Quick and easy client-side JavaScript search with Lunr.js" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/10/creating-light-and-dark-themes-for-websites-correctly-using-prefers-color-scheme" title="Creating light and dark themes for websites the right way using prefers-color-scheme">Creating light and dark themes for websites the right way using prefers-color-scheme</a><span class="muted"> / Oct 2021</span>
#         <div class="excerpt">
#             Blur the line between desktop and web by letting the OS style your website or webapp.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-10-10-creating-light-and-dark-themes-for-websites-correctly-using-prefers-color-scheme.gif" alt="Banner image for Creating light and dark themes for websites the right way using prefers-color-scheme" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/10/make-linux-apps-for-notion-mastodon-webapps-using-nativefier" title="Make Linux apps for Notion, Mastodon, or any web app using Nativefier">Make Linux apps for Notion, Mastodon, or any web app using Nativefier</a><span class="muted"> / Oct 2021</span>
#         <div class="excerpt">
#             Notion is an awesome life manager. And Mastodon is great for decentralised internet shenanigans. With Nativefier, I can now enjoy them as apps on Ubuntu 20.04.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-10-10-make-linux-apps-for-notion-mastodon-webapps-using-nativefier-banner.png" alt="Banner image for Make Linux apps for Notion, Mastodon, or any web app using Nativefier" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/10/inserting-dynamic-data-into-jekyll-static-sites-using-python-or-bash" title="Inserting dynamic data into Jekyll static sites using Python or Bash">Inserting dynamic data into Jekyll static sites using Python or Bash</a><span class="muted"> / Oct 2021</span>
#         <div class="excerpt">
#             Auto-generate Jekyll configuration files with content and avoid creating an API backend.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/08/introduction-to-ansible" title="Introduction to Ansible">Introduction to Ansible</a><span class="muted"> / Aug 2021</span>
#         <div class="excerpt">
#             Ansible is the answer to custom scripts and tooling that eventually snowball into a kludge which breaks more things than it fixes.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/08/introduction-to-yaml" title="Introduction to YAML">Introduction to YAML</a><span class="muted"> / Aug 2021</span>
#         <div class="excerpt">
#             What is YAML and why is it about time we started using it?
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/08/introduction-to-jekyll" title="Introduction to Jekyll">Introduction to Jekyll</a><span class="muted"> / Aug 2021</span>
#         <div class="excerpt">
#             Jekyll is a framework for building websites - write your content in Markdown, use HTML/CSS for structure and presentation, and Jekyll compiles it all into static HTML. No servers. No backends. No fuss.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2016-08-15-introduction-to-jekyll-new-article.png" alt="Banner image for Introduction to Jekyll" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/08/multi-machine-setup-and-configuration-with-vagrant" title="Multi-machine Setup and Configuration with Vagrant">Multi-machine Setup and Configuration with Vagrant</a><span class="muted"> / Aug 2021</span>
#         <div class="excerpt">
#             If you ever need to test an app and a database, did you know you can use Vagrant to bring up multiple testing machines at once? Here's how.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/08/provisioning-with-vagrant" title="Provisioning with Vagrant">Provisioning with Vagrant</a><span class="muted"> / Aug 2021</span>
#         <div class="excerpt">
#             Ansible works well to provision a Vagrant box with everything installed from the get-go.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/08/introduction-to-vagrant" title="Introduction to Vagrant">Introduction to Vagrant</a><span class="muted"> / Aug 2021</span>
#         <div class="excerpt">
#             Vagrant helps you run other operating systems on your computer, meaning you can build things, test things, and do crazy shit without blowing up your own system.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/08/a-guide-to-web-scraping-in-python-using-beautifulsoup" title="A Guide to Web Scraping in Python using BeautifulSoup">A Guide to Web Scraping in Python using BeautifulSoup</a><span class="muted"> / Aug 2021</span>
#         <div class="excerpt">
#             Web-scraping is a useful but often neglected technical skill. The BeautifulSoup library in Python makes extracting HTML from web pages easy. Do with that what you will ;)
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/08/using-variables-in-jekyll-to-define-custom-content" title="Using variables in Jekyll to define custom content">Using variables in Jekyll to define custom content</a><span class="muted"> / Aug 2021</span>
#         <div class="excerpt">
#             I recently discovered that Jekyll's config.yml can be used to define custom variables for reusing content. I feel like I've been living under a rock all this time. But to err over and over again is human.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/07/the-evolution-of-ayushsharma-in" title="The evolution of ayushsharma.in: Jekyll, Bootstrap, Netlify, static websites, and responsive design.">The evolution of ayushsharma.in: Jekyll, Bootstrap, Netlify, static websites, and responsive design.</a><span class="muted"> / Jul 2021</span>
#         <div class="excerpt">
#             In this article, I'll highlight some ideas for Jekyll collections, blog category pages, responsive web-design, and netlify.toml to make static website maintenance a breeze.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-07-15-the-evolution-of-ayushsharma-in-many-devices.png" alt="Banner image for The evolution of ayushsharma.in: Jekyll, Bootstrap, Netlify, static websites, and responsive design." />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/07/5-key-best-practices-for-sane-and-usable-terraform-setups" title="5 key best practices for sane and usable Terraform setups">5 key best practices for sane and usable Terraform setups</a><span class="muted"> / Jul 2021</span>
#         <div class="excerpt">
#             These are the top 5 lessons I've learned after 5 years of Terraform-ing.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/07/cloud-infrastructure-sast-terraform-checkov" title="Cloud Infrastructure SAST: Scanning Terraform for security vulnerabilities and non-compliance using Checkov">Cloud Infrastructure SAST: Scanning Terraform for security vulnerabilities and non-compliance using Checkov</a><span class="muted"> / Jul 2021</span>
#         <div class="excerpt">
#             In this article I explore Checkov, a static code analysis tool for Terraform.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-07-13-cloud-infrastructure-sast-terraform-checkov.svg" alt="Banner image for Cloud Infrastructure SAST: Scanning Terraform for security vulnerabilities and non-compliance using Checkov" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/07/terraform-plus-helm-a-match-made-in-heaven-hell" title="Terraform + Helm: A match made in heaven/hell?">Terraform + Helm: A match made in heaven/hell?</a><span class="muted"> / Jul 2021</span>
#         <div class="excerpt">
#             I've just discovered that Terraform can deploy Helm Charts as well. But I'm not sure if I like it.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2021-07-12-terraform-plus-helm-a-match-made-in-heaven-hell-choices.svg" alt="Banner image for Terraform + Helm: A match made in heaven/hell?" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/07/automating-argocd-using-argocd" title="Automating ArgoCD using ArgoCD!">Automating ArgoCD using ArgoCD!</a><span class="muted"> / Jul 2021</span>
#         <div class="excerpt">
#             In this tutorial, I will show you how to automatically create multiple Applications in ArgoCD using ArgoCD!
#
#             <img src="https://www.ayush.nz/static/images/img-normal/automating-argocd-with-argocd-deployment.png" alt="Banner image for Automating ArgoCD using ArgoCD!" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2021/07/getting-started-with-argocd" title="Getting started with ArgoCD">Getting started with ArgoCD</a><span class="muted"> / Jul 2021</span>
#         <div class="excerpt">
#             In this post we meet ArgoCD: a simple pull-based GitOps deployment tool which syncs K8s manifest files with a cluster for easy and no-nonsense deployments.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/getting-started-with-argocd-successful-nginx-deployment.png" alt="Banner image for Getting started with ArgoCD" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/09/creating-ready-to-use-aws-security-groups-using-terraform-registry-named-groups-and-named-rules" title="Creating ready-to-use AWS Security Groups using Terraform Registry, Named Groups, and Named Rules">Creating ready-to-use AWS Security Groups using Terraform Registry, Named Groups, and Named Rules</a><span class="muted"> / Sep 2020</span>
#         <div class="excerpt">
#             Create parameterized AWS security groups quickly and consistently with Terraform Registry.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2020-09-11-creating-ready-to-eat-aws-security-groups-using-terraform-registry-named-groups-and-named-rules.png" alt="Banner image for Creating ready-to-use AWS Security Groups using Terraform Registry, Named Groups, and Named Rules" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/09/creating-aws-vpcs-in-2-minutes-with-terraform-registry" title="Creating AWS VPCs in 2 minutes with Terraform Registry">Creating AWS VPCs in 2 minutes with Terraform Registry</a><span class="muted"> / Sep 2020</span>
#         <div class="excerpt">
#             Create parameterized AWS VPCs quickly and consistently with Terraform Registry.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/06/continuous-delivery-on-gitlab-pushing-docker-images-to-dockerhub-using-gitlab-pipelines" title="Continuous delivery on GitLab: Pushing Docker images to DockerHub using GitLab Pipelines">Continuous delivery on GitLab: Pushing Docker images to DockerHub using GitLab Pipelines</a><span class="muted"> / Jun 2020</span>
#         <div class="excerpt">
#             Build and push Docker images to DockerHub using GitLab's Pipelines feature.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/06/configuring-elasticsearch-snapshots-using-slm-on-google-compute-engine" title="Configuring Elasticsearch snapshots using SLM on Google Compute Engine">Configuring Elasticsearch snapshots using SLM on Google Compute Engine</a><span class="muted"> / Jun 2020</span>
#         <div class="excerpt">
#             A tutorial on how to configure automatic snapshots of Elasticsearch using the in-built Snapshot Lifecycle Manager on Google Compute Engine.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/06/working-from-home-and-software-engineering" title="​​Working From Home and Software Engineering">​​Working From Home and Software Engineering</a><span class="muted"> / Jun 2020</span>
#         <div class="excerpt">
#             Your time and attention is your primary resource, so deploy it wisely.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/04/the-virus-and-the-cloud-tips-on-aws-cost-saving" title="​​The Virus ​😷​ and the Cloud ​⛅​: Tips on AWS cost-saving in these weird ​🤯​ times">​​The Virus ​😷​ and the Cloud ​⛅​: Tips on AWS cost-saving in these weird ​🤯​ times</a><span class="muted"> / Apr 2020</span>
#         <div class="excerpt">
#             2020 is the year startups are trying to save aggresively on cloud spend. I list down some key learnings based on my experience.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/03/replicating-bitbucket-pipelines-on-your-laptop-for-local-debugging" title="Replicating Bitbucket Pipelines on your laptop for local debugging">Replicating Bitbucket Pipelines on your laptop for local debugging</a><span class="muted"> / Mar 2020</span>
#         <div class="excerpt">
#             I love Bitbucket Pipelines, and debugging them on your laptop is even easier thanks to Docker containers. I'll show you how to debug Serverless deployments and diagnose broken builds.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/02/cloning-another-bitbucket-repo-in-bitbucket-pipelines" title="Cloning another Bitbucket repository in Bitbucket Pipelines">Cloning another Bitbucket repository in Bitbucket Pipelines</a><span class="muted"> / Feb 2020</span>
#         <div class="excerpt">
#             I'll show you how to allow one Bitbucket repo to clone another during a Pipeline build.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2020/02/deploying-git-submodules-in-bitbucket-pipelines" title="Deploying git submodules in Bitbucket Pipelines">Deploying git submodules in Bitbucket Pipelines</a><span class="muted"> / Feb 2020</span>
#         <div class="excerpt">
#             Git submodules makes it easy have repos for common dependencies, but how to actually clone them in your Bitbucket Pipeline?
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2019/08/automating-ecr-container-builds-using-bitbucket-pipelines" title="Automating Amazon Elastic Container (ECR) container builds using Bitbucket Pipelines">Automating Amazon Elastic Container (ECR) container builds using Bitbucket Pipelines</a><span class="muted"> / Aug 2019</span>
#         <div class="excerpt">
#             I'll show you how to build a Docker image in a Pipeline and push it to a container registry, in this case Amazon ECR.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/2019-08-30-automating-ecr-container-builds-using-bitbucket-pipelines-ecr-overview.png" alt="Banner image for Automating Amazon Elastic Container (ECR) container builds using Bitbucket Pipelines" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2019/08/taming-aws-costs-with-cost-and-usage-reports-and-aws-athena" title="Taming AWS costs with Cost and Usage Reports + AWS Athena">Taming AWS costs with Cost and Usage Reports + AWS Athena</a><span class="muted"> / Aug 2019</span>
#         <div class="excerpt">
#             AWS Cost &amp; Usage Reports with AWS Athena are vital for understanding cloud spend. I'll show you some handy Athena queries to break things down.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2019/06/exporting-bitucket-repos-pipelines-python" title="Exporting Bitucket repositories and Pipelines with Python">Exporting Bitucket repositories and Pipelines with Python</a><span class="muted"> / Jun 2019</span>
#         <div class="excerpt">
#             Bitbucket doesn't offer a dashboard yet, or an easy way to fetch information for all your repos and Pipelines. So I wrote a handy Python script for the job. It's great for configuring alerts or building near-real-time dashboards!
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2019/06/rediscovering-logo-with-bob-the-turtle" title="Rediscovering Logo with Bob the turtle">Rediscovering Logo with Bob the turtle</a><span class="muted"> / Jun 2019</span>
#         <div class="excerpt">
#             My very first programming language was Logo! I can still remember guiding that fuzzy little on-screen turtle to draw simple and complex shapes. So I found the Logo Python module and took a walk down memory lane.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/rediscovering-logo-python-turtle-sierpinski-triangle.jpg" alt="Banner image for Rediscovering Logo with Bob the turtle" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2019/05/automating-serverless-framework-deployments-using-bitbucket-pipelines" title="Automating Serverless framework deployments using Bitbucket Pipelines">Automating Serverless framework deployments using Bitbucket Pipelines</a><span class="muted"> / May 2019</span>
#         <div class="excerpt">
#             The open-source Serverless framework makes it easy to build and deploy Lambda stacks. I'll walk you through deploying Serverless apps automatically using Pipelines.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/bitbucket-pipelines-serverless-framework.png" alt="Banner image for Automating Serverless framework deployments using Bitbucket Pipelines" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2019/05/automating-aws-lambda-deployments-using-bitbucket-pipelines-bitbucket-pipes" title="Automating AWS Lambda deployments using Bitbucket Pipelines and Bitbucket Pipes">Automating AWS Lambda deployments using Bitbucket Pipelines and Bitbucket Pipes</a><span class="muted"> / May 2019</span>
#         <div class="excerpt">
#             Pipes is another great Continuous Delivery feature in Bitbucket: pre-built, ready-to-use, and parameterized deployment jobs.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2019/03/algorithms-in-python-exchange-sorts" title="Algorithms in Python: Exchange Sorts">Algorithms in Python: Exchange Sorts</a><span class="muted"> / Mar 2019</span>
#         <div class="excerpt">
#             Notes on implementing the basic Exchange sort algorithms in Python.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2019/01/the-three-ways-of-devops-notes-on-the-phoenix-project" title="The Three Ways of DevOps: Notes on The Phoenix Project">The Three Ways of DevOps: Notes on The Phoenix Project</a><span class="muted"> / Jan 2019</span>
#         <div class="excerpt">
#             The Phoenix Project is one of the most approachable books for DevOps available today. Highly recommended, especially if you don't already know Conway's Law.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/10/working-with-numpy-in-python" title="Working with NumPy in Python">Working with NumPy in Python</a><span class="muted"> / Oct 2018</span>
#         <div class="excerpt">
#             My Udacity Python Nanodegree introduced using NumPy to handle large arrays and datasets in Python. I put some notes togther for referencing later.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/09/data-types-in-python" title="Data Types in Python">Data Types in Python</a><span class="muted"> / Sep 2018</span>
#         <div class="excerpt">
#             Some quick notes describing the basic data types in Python3 and their features.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/09/dockerizing-tweet-toot-a-practical-guide-to-deploying-your-app-using-docker" title="Dockerizing Tweet-Toot: A practical guide to deploying your app using Docker">Dockerizing Tweet-Toot: A practical guide to deploying your app using Docker</a><span class="muted"> / Sep 2018</span>
#         <div class="excerpt">
#             Tweet-Toot is my personal project, a Twitter relay for the Mastodon social network. I recently dockerized the setup and put these notes together to explain the process.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/09/sublime-text-3-setup-for-jekyll-development" title="SublimeText 3 setup for Jekyll development">SublimeText 3 setup for Jekyll development</a><span class="muted"> / Sep 2018</span>
#         <div class="excerpt">
#             SublimeText has some cool plugins for setting up a basic Jekyll development environment. Take a look.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/09/gartners-magic-quadrants-a-summary-of-cloud-infrastructure-as-a-service-providers-over-the-last-5-years" title="Gartner's Magic Quadrants: A summary of cloud Infrastructure-as-a-Service providers over the last 5 years">Gartner's Magic Quadrants: A summary of cloud Infrastructure-as-a-Service providers over the last 5 years</a><span class="muted"> / Sep 2018</span>
#         <div class="excerpt">
#             Gartner's Magic Quadrants was one of the the first industry reports I read which covered where the cloud vendor's were headed and what their strengths and weaknesses were. I took some time to consolidate the Gartner findings over the last 5 years for comparison.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/gartner-magic-quadrant-for-cloud-infrastructure-as-a-service-worldwide-2018.png" alt="Banner image for Gartner's Magic Quadrants: A summary of cloud Infrastructure-as-a-Service providers over the last 5 years" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/09/tweet-toot-building-a-bot-for-mastodon-using-python" title="Tweet-Toot: Building a bot for Mastodon using Python">Tweet-Toot: Building a bot for Mastodon using Python</a><span class="muted"> / Sep 2018</span>
#         <div class="excerpt">
#             I joined the Mastodon social network in 2016 and felt a need for building a Twitter relay. We all left the birdsite for many reasons but not the people we met. So this project is a way to bring some of them over to Mastodon, in practice if not in spirit.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/07/moving-from-cloudflare-to-stackpath" title="Moving from CloudFlare to StackPath">Moving from CloudFlare to StackPath</a><span class="muted"> / Jul 2018</span>
#         <div class="excerpt">
#             I love Cloudflare, but after facing some issues with TTFB I decided to move to StackPath, which proved to be a lot faster and feature-rich.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/cloudflare-stackpath-notes.ayushsharma.in-stackpath_ttfb.png" alt="Banner image for Moving from CloudFlare to StackPath" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/07/understanding-vendor-lock-in-and-breaking-the-cycle" title="Understanding vendor lock-in and breaking the cycle">Understanding vendor lock-in and breaking the cycle</a><span class="muted"> / Jul 2018</span>
#         <div class="excerpt">
#             I went through one of Gartner's reports, and it says the key to breaking vendor lock-in is to commit fully to a single technology vendor, be it a cloud software provider, a social network, or our favorite sharing app. It seems controversial on the surface, but I wanted to jot down some quick notes. Maybe the approach is worth experimenting with?
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/07/rolling-clusters-for-deployment-with-terraform" title="Rolling clusters for deployment with Terraform">Rolling clusters for deployment with Terraform</a><span class="muted"> / Jul 2018</span>
#         <div class="excerpt">
#             Terraform enables more than infrastructure provisioning, you can even use it for deployments. Combine it with Packer, and you can have a very powerful immutable rolling deployment pipeline.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2018/07/working-with-terraform-modules" title="Working with Terraform Modules">Working with Terraform Modules</a><span class="muted"> / Jul 2018</span>
#         <div class="excerpt">
#             Terraform's Modules feature allows quickly building re-usable infrastructure templates to provision cloud environments repeatably. These notes will help set up a basic application for high-availability.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/10/getting-started-with-terraform" title="Getting started with Terraform">Getting started with Terraform</a><span class="muted"> / Oct 2017</span>
#         <div class="excerpt">
#             A basic walkthrough of Terraform, the open-source, cloud-agnostic IaC tool by HashiCorp, the makers of Vagrant.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/upgrading-to-http2" title="Upgrading to HTTP/2">Upgrading to HTTP/2</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             It's about time we all move our web properties to HTTP/2. I list down some gotchas for those looking to migrate.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/http-security-headers-referrer-policy" title="HTTP security headers: Referrer-Policy">HTTP security headers: Referrer-Policy</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             The web is a collection of inter-connected pages. This means chances are good that someone landing on your website is coming from another one, and when they leave your website, they take a lot of identifiable information with them. HTTP/2 allows you to control what happens to the referrer information when users leave your website.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/http-security-headers-x-content-type-options" title="HTTP security headers: X-Content-Type-Options">HTTP security headers: X-Content-Type-Options</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             HTTP/2 introduced a new feature which basically just turns off an old default feature: the browser's hankering for figuring out the content type of a resource. Why and how should we turn it off?
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/http-security-headers-x-frame-options" title="HTTP security headers: X-Frame-Options">HTTP security headers: X-Frame-Options</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             Inline-frames enable very basic phishing attacks. You can just include a bank's main website within your own website and lure the user to handover their passwords. HTTP2/ comes with built-in protection against this kind of threat.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/http-security-headers-http-strict-transport-security" title="HTTP security headers: HTTP-Strict-Transport-Security">HTTP security headers: HTTP-Strict-Transport-Security</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             HSTS is a security feature which prevents users from accessing your website over non-secure HTTP. It comes with HTTP/2, is easy to turn on, but very hard to turn off. Here's the why and how.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/http-security-headers-x-xss-protection" title="HTTP security headers: X-XSS-Protection">HTTP security headers: X-XSS-Protection</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             HTTP/2 comes with built-in protection for XSS. Here's what it does and how to turn it on.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/http-security-headers-content-security-policy" title="HTTP security headers: Content-Security-Policy">HTTP security headers: Content-Security-Policy</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             HTTP/2's CSP let's you define a white-list of what's allowed and what's blocked on your website. This lets browsers block third-party trackers which try to annoy/harm your users. Here's the why and how.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/im-killing-disqus-comments-on-my-blog-heres-why" title="I'm killing Disqus comments on my blog. Here's why.">I'm killing Disqus comments on my blog. Here's why.</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             I added the Disqus commenting platform to my blog some time ago. And then I found out that it was loading WAY TOO MANY tracking cookies inline and profiling my website users. This is how you build Orwellian software. And shitty software.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/disqus-comments-ad-tracking-domains.jpg" alt="Banner image for I'm killing Disqus comments on my blog. Here's why." />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/posting-messages-to-slack-using-incoming-webhooks-and-python-requests-api" title="Posting messages to Slack using incoming webhooks and Python3 Requests API">Posting messages to Slack using incoming webhooks and Python3 Requests API</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             Slack has become a favorite of DevOps/SRE teams across the globe. It's a very easy-to-use and programmatic messaging platform. Here's the quick and easy process to posting messages to your Slack group from Python.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/using-packer-and-ansible-to-create-immutable-servers-deploying-code-and-recycling-instances" title="Using Packer and Ansible to create immutable servers, deploying code, and recycling instances">Using Packer and Ansible to create immutable servers, deploying code, and recycling instances</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             Packer is an amazing golden image builder. Ansible is a great deployment tool. So let's use them together!
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/getting-started-with-packer" title="Getting started with Packer">Getting started with Packer</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             Packer. Basically Docker for whole VMs. Another great tool by HashiCorp, this one modernises an old formula but retains the simplicity. Building immutable servers was never this easy.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/the-different-ways-ive-deployed-code-over-the-years-the-road-to-immutable-servers" title="The different ways I've deployed code over the years: the road to Immutable Servers">The different ways I've deployed code over the years: the road to Immutable Servers</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             I took a walk down memory lane to try and figure out how much my daily work has changed. The concepts are still the same, but the tools have become bigger, because our needs have shifted dramatically over the years.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/09/testing-aws-elastic-load-balancer-health-check-endpoints-with-python" title="Testing AWS Elastic Load Balancer health check endpoints with Python">Testing AWS Elastic Load Balancer health check endpoints with Python</a><span class="muted"> / Sep 2017</span>
#         <div class="excerpt">
#             A quick script for ad-hoc health-checking of load balancer instances.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/08/complete-nginx-monitoring-with-collectd-and-influxdb" title="Complete Nginx Monitoring with Collectd and InfluxDB">Complete Nginx Monitoring with Collectd and InfluxDB</a><span class="muted"> / Aug 2017</span>
#         <div class="excerpt">
#             I recently discovered InfluxDB as a great write-heavy database for storing metrics. These are my notes on monitoring the golden signals in Nginx using Collectd and InfluxDB.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/08/deploying-jekyll-blog-automatically-using-bitbucket-pipelines" title="Deploying Jekyll blog automatically using Bitbucket Pipelines">Deploying Jekyll blog automatically using Bitbucket Pipelines</a><span class="muted"> / Aug 2017</span>
#         <div class="excerpt">
#             Because why not? Here's how to build your Jekyll website and deploy it to a VM of your choice.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/bitbucket-pipelines-successful-deployment-screen.jpg" alt="Banner image for Deploying Jekyll blog automatically using Bitbucket Pipelines" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/08/migrating-mysql-database-tables-to-influxdb" title="Migrating MySQL database tables to InfluxDB">Migrating MySQL database tables to InfluxDB</a><span class="muted"> / Aug 2017</span>
#         <div class="excerpt">
#             If you ever need to migrate a MySQL database to InfluxDB, say if you were using MySQL as a metrics database because you were too busy not knowing Influx even existed, then this handy Python script can do the job and take care of schema migrations too.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/08/backing-up-influxdb-databases-to-s3" title="Backing up InfluxDB databases to S3">Backing up InfluxDB databases to S3</a><span class="muted"> / Aug 2017</span>
#         <div class="excerpt">
#             A handy bash script to backup your InfluxDB database to AWS S3; great for cron jobs.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/08/setting-up-grafana-to-use-collectd-and-influxdb" title="Setting Up Grafana to use Collectd and InfluxDB">Setting Up Grafana to use Collectd and InfluxDB</a><span class="muted"> / Aug 2017</span>
#         <div class="excerpt">
#             Grafana provides out-of-the-box support for InfluxDB, so visualising the metrics you're collecting using Collectd, etc., is straightforward. Here's how to do it.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/grafana-user-cpu-percentage-and-free-memory-dashboard.jpg" alt="Banner image for Setting Up Grafana to use Collectd and InfluxDB" />
# ...
#         <div class="excerpt">
#             I pulled the data for technology incidents for the major cloud services. The findings were pretty interesting.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/03/i-have-something-to-say-ii" title="I Have Something to Say II">I Have Something to Say II</a><span class="muted"> / Mar 2017</span>
#         <div class="excerpt">
#             These have been the confessions of a firefighter who ignored the smoke.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/03/using-weighted-geo-failover-routeing-in-route-53" title="Using Weighted, Geo and Fail-over Routeing in Route 53">Using Weighted, Geo and Fail-over Routeing in Route 53</a><span class="muted"> / Mar 2017</span>
#         <div class="excerpt">
#             At work, one of my recent projects involved setting up a multi-region failover with weighted-routing support. Thankfully, Route53 has all of these built-in. Here's how to do it.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/aws-route-53-configuration-using-geo-weighted-and-fail-over-routeing.jpg" alt="Banner image for Using Weighted, Geo and Fail-over Routeing in Route 53" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/03/you-might-still-need-a-staging-server-in-2017" title="You still might need a staging server in 2017">You still might need a staging server in 2017</a><span class="muted"> / Mar 2017</span>
#         <div class="excerpt">
#             It's 2017 and the cloud has matured by leaps and bounds. So do we still need staging servers?
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/03/aws-gcs-and-azure-incidents-in-2016" title="AWS, GCS, Azure and Digital Ocean incidents in 2016">AWS, GCS, Azure and Digital Ocean incidents in 2016</a><span class="muted"> / Mar 2017</span>
#         <div class="excerpt">
#             I pulled the data for technology incidents on the major cloud platforms. The findings were pretty interesting.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/03/i-have-something-to-say" title="I Have Something to Say">I Have Something to Say</a><span class="muted"> / Mar 2017</span>
#         <div class="excerpt">
#             Ten years from now, if or when I am in another job, no one is going to care whether I ran my production servers with my heart and soul. They will care if I saved money, they will care if I ran it efficiently, but you can do those things while still compromising your values.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/02/connecting-vpcs-in-2-aws-regions-site-to-site-vpn" title="Connecting VPCs in 2 AWS Regions (Site-to-site VPN)">Connecting VPCs in 2 AWS Regions (Site-to-site VPN)</a><span class="muted"> / Feb 2017</span>
#         <div class="excerpt">
#             A step-by-step guide for connecting 2 AWS VPSs using self-hosted StrongSwan VPNs.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/02/installing-php7-fpm-mysql-5.7-nginx-1.10-on-ubuntu-16.04" title="Installing PHP 7 FPM + MySQL 5.7 + Nginx 1.10 on Ubuntu 16.04">Installing PHP 7 FPM + MySQL 5.7 + Nginx 1.10 on Ubuntu 16.04</a><span class="muted"> / Feb 2017</span>
#         <div class="excerpt">
#             These are instructions for installing PHP7, MySQL 5.7 and Nginx 1.10 on Ubuntu 16.04. Very copy-paste-able.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/02/working-with-logical-volume-manager-lvm" title="Working with Logical Volume Manager (LVM)">Working with Logical Volume Manager (LVM)</a><span class="muted"> / Feb 2017</span>
#         <div class="excerpt">
#             Some notes on Logical Volume Manager. What it is, why it is, and how to use it.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/01/fiddling-with-logrotate" title="Fiddling with Logrotate">Fiddling with Logrotate</a><span class="muted"> / Jan 2017</span>
#         <div class="excerpt">
#             Logrotate is one of those built-in Linux things that we don't use often enough. Rotating logs, archiving them to S3, pushing them to some remote server/endpoint, etc. It's all doable with Logrotate.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/01/notes-on-aws-route53" title="AWS Route 53 Notes">AWS Route 53 Notes</a><span class="muted"> / Jan 2017</span>
#         <div class="excerpt">
#             Route53: what, why, how, why not.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2017/01/aws-ebs-types-read-write-benchmarks" title="AWS EBS Types Read/Write Benchmarks">AWS EBS Types Read/Write Benchmarks</a><span class="muted"> / Jan 2017</span>
#         <div class="excerpt">
#             I ran hdparm and dd on GP2, PIOPS, SC1, ST1, and Magnetic EBS volumes. Check out the results.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/10/logging-aws-spot-instance-termination" title="Logging AWS spot instance termination">Logging AWS spot instance termination</a><span class="muted"> / Oct 2016</span>
#         <div class="excerpt">
#             AWS spot instances provide 90% savings over on-demand servers. The downside? AWS can yank them whenever they want and you have 2 minutes to back things up. How do you know when the starting pistol fires?
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/10/decompressing-request-using-gzip-with-nginx" title="Decompressing request using GZIP with Nginx">Decompressing request using GZIP with Nginx</a><span class="muted"> / Oct 2016</span>
#         <div class="excerpt">
#             If you're using a Lua module with Nginx, then decompressing GZIPped data requires some extra handling.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/10/compressing-output-using-gzip-with-php-5.3" title="Compressing output using GZIP with PHP 5.3">Compressing output using GZIP with PHP 5.3</a><span class="muted"> / Oct 2016</span>
#         <div class="excerpt">
#             It's pretty hard to compress output with GZIP in PHP 5.3, but in case you ever need to, here's how.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/introduction-to-load-balancing-with-nginx" title="Introduction to Load-balancing with Nginx">Introduction to Load-balancing with Nginx</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             I'll explore the basics of self-hosted load-balancing with Nginx using a convenient testing setup using Vagrant.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/working-of-a-load-balancer.jpg" alt="Banner image for Introduction to Load-balancing with Nginx" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/reading-jwt-token-in-phalcon" title="Reading JWT token in Phalcon">Reading JWT token in Phalcon</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             Here's how to read a response JSON web token in PHP Phalcon.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/setting-custom-404-controller-in-phalcon" title="Setting Custom 404 Controller in Phalcon">Setting Custom 404 Controller in Phalcon</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             After CodeIgniter, Phalcon was the second PHP framework that I used. Blazingly fast and easy-to-use, one of the first things I did was create a custom 404 response controller.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/dns-record-types" title="DNS Record Types">DNS Record Types</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             A quick guide to the different DNS record types.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/securing-nginx-with-lets-encrypt-free-ssl-certificate" title="Securing Nginx with Let's Encrypt Free SSL Certificate">Securing Nginx with Let's Encrypt Free SSL Certificate</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             Let's Encrypt is the self-hosted, industry-standard method of generating SSL certificates for your applications. If you're still paying for SSL certificates you're doing it wrong.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/vertical-scaling-vs-horizontal-scaling" title="Vertical Scaling vs Horizontal Scaling">Vertical Scaling vs Horizontal Scaling</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             The differences between vertical and horizontal scaling may be simple, but they're critical to using cloud technologies effectively.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/essential-vim-keyboard-shortcuts" title="Essential VIM Keyboard Shortcuts">Essential VIM Keyboard Shortcuts</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             A quick guide of essential VIM shortcuts.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/notes-on-aws-sqs" title="Notes on AWS SQS">Notes on AWS SQS</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             AWS SQS: what, why, how, why not.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/mysql-physical-backup-with-innobackupex" title="MySQL Physical Backup with Innobackupex">MySQL Physical Backup with Innobackupex</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             Innobackupex, part of Percona Xtrabackup, can perform physical backups of your MySQL databases.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/introduction-to-mysql-partitioning" title="Introduction to MySQL Partitioning">Introduction to MySQL Partitioning</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             MySQL partitioning basics: what, why, and how.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/introduction-to-fluentd" title="Introduction to Fluentd">Introduction to Fluentd</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             The legacy logging infrastructure we have to deal with today was designed for humans and not machines, so a lot of effort is wasted trying to make backend systems understand log data.
#
#             <img src="https://www.ayush.nz/static/images/img-normal/fluentd-architecture.jpg" alt="Banner image for Introduction to Fluentd" />
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/nano-keyboard-shortcuts" title="NANO Keyboard Shortcuts">NANO Keyboard Shortcuts</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             A quick reference of NANO shortcuts.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/json-web-tokens" title="JSON Web Tokens">JSON Web Tokens</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             The following document assesses the possibility of using JWT (pronounced "jot") as a token exchange mechanism for APIs.
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
# <div class="article-link">
#     <p>
#         <a href="/2016/08/hello-world" title="Hello @World">Hello @World</a><span class="muted"> / Aug 2016</span>
#         <div class="excerpt">
#             Hello, World, you little blue thing...
#
#
#         </div>
#         <p>
#
#         </p>
#     </p>
# </div>
#
#   </main>
# </body>
#
# <footer>
#     <div id="footer-home">
#         <a href="/" title="Home is where our story begins…"><img
#                 src="https://www.ayush.nz/static/images/meta/favicon/android-chrome-192x192.png"
#                 width="52" height="52" alt="Home is where our story begins…"></a>
#     </div>
#
#     <p>
#         <a href="/" title="Home">Home 🏠</a>
# <a href="/life-stuff" title="Life stuff">Life stuff ☕</a>
# <a href="/technology" title="Technology">Technology 🛸</a>
# <a href="/video-games" title="Video Games">Video Games 🕹️</a>
# <a href="/books" title="Books">Books 📖</a>
# <a href="/photos" title="Photos">Photos 📖</a>
# <a href="/about" title="About Me">About Me 🙌</a>
# <a href="/feed.xml" title="Subscribe!">Subscribe! 🔔</a>
#     </p>
#
#     <p>
#         <div class="row row-cols-1 row-cols-md-4 g-3">
#     <div class="col">
#         <a class="align-middle w-100 text-dark btn px-1 py-2 btn-success" rel="me" href="https://us6.list-manage.com/contact-form?u=768b89007e44f7f05c5e7539b&form_id=6eae4dbf8e9d1475f967c8447e3080ac" title="Email" target="_blank"><i class="fas fa-at mx-2"></i>Email</a>
#         //
#         <a class="align-middle w-100 text-dark btn px-1 py-2 btn-success" rel="me" href="https://nz.linkedin.com/in/ayush-sharma-in" title="LinkedIn" target="_blank"><i class="fab fa-linkedin-in mx-2"></i>LinkedIn</a>
#         //
#         <a class="align-middle w-100 text-dark btn px-1 py-2 btn-success" rel="me" href="https://mastodon.nz/@ayushsharma22" title="Mastodon" target="_blank"><i class="fab fa-mastodon mx-2"></i>Mastodon</a>
#     </div>
# </div>
#     </p>
#
#     <p>
#         © <span id="currentyear"></span> Ayush Sharma // <a href="https://gitlab.com/ayush-sharma/ayushsharma-in"
#             target="_blank">source</a> // <a href="/feed.xml" target="_blank">subscribe</a> //
#         <a href="https://us6.list-manage.com/contact-form?u=768b89007e44f7f05c5e7539b&form_id=6eae4dbf8e9d1475f967c8447e3080ac" target="_blank">contact</a>
#         <script>
#             let date = new Date().getFullYear();
#             document.getElementById("currentyear").textContent = date;
#         </script>
#     </p>
# </footer>
#
# </html>

# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint

url = 'https://notes.ayushsharma.in/technology'
data = requests.get(url)

my_data = []

html = BeautifulSoup(data.text, 'html.parser')
articles = html.select('a.post-card')

for article in articles:

    title = article.select('.card-title')[0].get_text()
    excerpt = article.select('.card-text')[0].get_text()
    pub_date = article.select('.card-footer small')[0].get_text()

    my_data.append({"title": title, "excerpt": excerpt, "pub_date": pub_date})

pprint(my_data)
# Out:
# []

# %% [markdown]
# #Another Example

# %%
#importing the BeautifulSoup Library  
  
import bs4  
import requests  
  
#Creating the requests  
  
res = requests.get("https://en.wikipedia.org/wiki/Machine_learning")  
print("The object type:",type(res))  
  
# Convert the request object to the Beautiful Soup Object  
soup = bs4.BeautifulSoup(res.text,"html.parser")  
print("The object type:",type(soup))
# Out:
# The object type: <class 'requests.models.Response'>
# The object type: <class 'bs4.BeautifulSoup'>

# %%
soup.select('.mw-headline')  
for i in soup.select('.mw-headline'):  
  print(i.text,end = ',')
# Out:
# History,Relationships to other fields,Artificial intelligence,Data compression,Data mining,Generalization,Statistics,Statistical physics, Theory,Approaches,Supervised learning,Unsupervised learning,Semi-supervised learning,Reinforcement learning,Dimensionality reduction,Other types,Self-learning,Feature learning,Sparse dictionary learning,Anomaly detection,Robot learning,Association rules,Models,Artificial neural networks,Decision trees,Support-vector machines,Regression analysis,Bayesian networks,Gaussian processes,Genetic algorithms,Belief functions,Training models,Federated learning,Applications,Limitations,Bias,Explainability,Overfitting,Other limitations and vulnerabilities,Model assessments,Ethics,Hardware,Neuromorphic/Physical Neural Networks,Embedded Machine Learning,Software,Free and open-source software,Proprietary software with free and open-source editions,Proprietary software,Journals,Conferences,See also,References,Sources,Further reading,External links,

# %% [markdown]
# #Flipkart

# %%
from bs4 import BeautifulSoup as soup  
from urllib.request import urlopen as uReq  
  
# Request from the webpage  
myurl = "https://www.flipkart.com/search?q=iphones&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"  
  
  
uClient  = uReq(myurl)  
page_html = uClient.read()  
uClient.close()  
  
page_soup = soup(page_html, features="html.parser")  
  
# print(soup.prettify(containers[0]))  
  
# This variable held all html of webpage  
containers = page_soup.find_all("div",{"class": "_3O0U0u"})  
# container = containers[0]  
# # print(soup.prettify(container))  
#  
# price = container.find_all("div",{"class": "col col-5-12 _2o7WAb"})  
# print(price[0].text)  
#  
# ratings = container.find_all("div",{"class": "niH0FQ"})  
# print(ratings[0].text)  
#  
# #  
# # print(len(containers))  
# print(container.div.img["alt"])  
  
# Creating CSV File that will store all data   
filename = "product1.csv"  
f = open(filename,"w")  
  
headers = "Product_Name,Pricing,Ratings\n"  
f.write(headers)  
  
for container in containers:  
    product_name = container.div.img["alt"]  
  
    price_container = container.find_all("div", {"class": "col col-5-12 _2o7WAb"})  
    price = price_container[0].text.strip()  
  
    rating_container = container.find_all("div",{"class":"niH0FQ"})  
    ratings = rating_container[0].text  
  
    print("product_name:"+product_name)  
    print("price:"+price)  
    print("ratings:"+ str(ratings))  
  
    edit_price = ''.join(price.split(','))  
    sym_rupee = edit_price.split("?")  
    add_rs_price = "Rs"+sym_rupee[1]  
    split_price = add_rs_price.split("E")  
    final_price = split_price[0]  
  
    split_rating = str(ratings).split(" ")  
    final_rating = split_rating[0]  
  
    print(product_name.replace(",", "|")+","+final_price+","+final_rating+"\n")  
    f.write(product_name.replace(",", "|")+","+final_price+","+final_rating+"\n")  
  
f.close()

# %% [markdown]
# #Javapoint Example

# %%
# importing the libraries  
from bs4 import BeautifulSoup  
import requests  
  
url="https://www.javatpoint.com/"  
  
# Make a GET request to fetch the raw HTML content  
html_content = requests.get(url).text  
  
# Parse the html content  
soup = BeautifulSoup(html_content, "html.parser")  
print(soup.prettify()) # print the parsed data of html
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-BMVLE5WY82">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-BMVLE5WY82');
#   </script>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <link href="https://static.javatpoint.com/images/favicon2.png" rel="SHORTCUT ICON"/>
#   <title>
#    Tutorials List - Javatpoint
#   </title>
#   <meta content="javatpoint, java tutorial, core java tutorial, beginners, professionals" name="keywords">
#    <meta content="Tutorials, Free Online Tutorials, Javatpoint provides tutorials and interview questions of all technology like java tutorial, android, java frameworks, javascript, ajax, core java, sql, python, php, c language etc. for beginners and professionals." name="description"/>
#    <link href="https://clients1.google.com" rel="preconnect"/>
#    <link href="https://googleads.g.doubleclick.net" rel="preconnect"/>
#    <link href="https://static.javatpoint.com" rel="preconnect"/>
#    <link href="https://www.google.com" rel="preconnect"/>
#    <link href="https://feedify.net" rel="preconnect"/>
#    <link href="https://clients1.google.com" rel="dns-prefetch"/>
#    <link href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/>
#    <link href="https://static.javatpoint.com" rel="dns-prefetch"/>
#    <link href="https://www.google.com" rel="dns-prefetch"/>
#    <link href="https://feedify.net" rel="dns-prefetch"/>
#    <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#    <meta content="yes" name="apple-mobile-web-app-capable"/>
#    <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#    <link href="https://www.javatpoint.com" rel="canonical">
#     <meta content="#4CAF50" name="theme-color">
#      <meta content="en_US" property="og:locale">
#       <meta content="article" property="og:type">
#        <meta content="Tutorials - Javatpoint" name="twitter:title" property="og:title"/>
#        <meta content="Tutorials, Free Online Tutorials, Javatpoint provides tutorials and interview questions of all technology like java tutorial, android, java frameworks, javascript, ajax, core java, sql, python, php, c language etc. for beginners and professionals." name="twitter:description" property="og:description"/>
#        <meta content="https://www.javatpoint.com" property="og:url"/>
#        <meta content="www.javatpoint.com" property="og:site_name"/>
#        <meta content="summary" name="twitter:card"/>
#        <meta content="@pagejavatpoint" name="twitter:site"/>
#        <meta content="www.javatpoint.com" name="twitter:domain"/>
#        <meta content="@pagejavatpoint" name="twitter:creator"/>
#        <meta content="NaYVz1vb9vgNxYaO7S6-16EJi3Q60kUuik1erUuFEYo" name="google-site-verification"/>
#        <style>
#         body{color:#202020}
#        </style>
#        <link href="https://static.javatpoint.com/link.css?v=5.6" media="all" rel="stylesheet" type="text/css">
#         <link href="https://www.javatpoint.com/manifest.json" rel="manifest"/>
#         <script data-cfasync="false" type="text/javascript">
#          (function(w, d) {
# 	var s = d.createElement('script');
# 	s.src = '//cdn.adpushup.com/37780/adpushup.js';
# 	s.crossOrigin='anonymous';
# 	s.type = 'text/javascript'; s.async = true;
# 	(d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s);
# 	w.adpushup = w.adpushup || {que:[]};
# })(window, document);
#         </script>
#         <script data-cfasync="false" type="text/javascript">
#          (function(w, d) { var s = d.createElement('script'); s.src = 'https://delivery.adrecover.com/37784/adRecover.js'; s.type = 'text/javascript'; s.async = true; (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s); })(window, document);
#         </script>
#        </link>
#       </meta>
#      </meta>
#     </meta>
#    </link>
#   </meta>
#  </head>
#  <body>
#   <div id="page" style="margin:-8px;background-color:#f5f5f4">
#    <div id="container">
#     <div class="header" id="headerpage">
#      <table style="width:100%;margin-bottom:5px">
#       <tr>
#        <td>
#         <div style="clear:both;float:left;width:230px;margin-top:15px;margin-left:10px;margin-right:10px">
#          <a href="https://www.javatpoint.com">
#           <img alt="Javatpoint Logo" src="https://static.javatpoint.com/images/logo/jtp-logo3.png"/>
#          </a>
#         </div>
#         <div style="float:left;width:60%;">
#          <script>
#           (function() { var cx = '005383125436438536544:y1edweedxwi'; var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true; gcse.src = 'https://cse.google.com/cse.js?cx=' + cx; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s); })();
#          </script>
#          <gcse:search>
#          </gcse:search>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="headermobile">
#      <div style="margin-top:10px;margin-left:48px;padding:0px;text-align:left;">
#       <span style="float:left">
#        <a href="https://www.javatpoint.com">
#         <img alt="Javatpoint Logo" src="https://static.javatpoint.com/images/logo/jtp-logo3.png"/>
#        </a>
#       </span>
#      </div>
#      <div style="margin:0px;padding:0px;clear:both">
#       <script>
#        (function() {
#     var cx = '005383125436438536544:y1edweedxwi';
#     var gcse = document.createElement('script');
#     gcse.type = 'text/javascript';
#     gcse.async = true;
#     gcse.src = 'https://cse.google.com/cse.js?cx=' + cx;
#     var s = document.getElementsByTagName('script')[0];
#     s.parentNode.insertBefore(gcse, s);
#   })();
#       </script>
#       <gcse:search>
#       </gcse:search>
#      </div>
#     </div>
#     <div id="link" style="clear:both">
#      <div class="ddsmoothmenu">
#       <ul>
#        <li>
#         <a href="https://www.javatpoint.com">
#          <img alt="home" src="https://static.javatpoint.com/images/icon/home.png">
#           Home
#          </img>
#         </a>
#        </li>
#        <li>
#         <a href="python-tutorial">
#          <img alt="python" src="https://static.javatpoint.com/images/icon/python.png"/>
#          Python
#         </a>
#        </li>
#        <li>
#         <a href="java-tutorial">
#          <img alt="java" src="https://static.javatpoint.com/images/icon/new/java2.png"/>
#          Java
#         </a>
#        </li>
#        <li>
#         <a href="javascript-tutorial">
#          <img alt="javascript" src="https://static.javatpoint.com/images/icon/js.png"/>
#          JavaScript
#         </a>
#        </li>
#        <li>
#         <a href="html-tutorial">
#          <img alt="html" src="https://static.javatpoint.com/images/icon/html.png"/>
#          HTML
#         </a>
#        </li>
#        <li>
#         <a href="sql-tutorial">
#          <img alt="sql" src="https://static.javatpoint.com/images/icon/sql.png"/>
#          SQL
#         </a>
#        </li>
#        <li>
#         <a href="php-tutorial">
#          <img alt="php" src="https://static.javatpoint.com/images/icon/php.png"/>
#          PHP
#         </a>
#        </li>
#        <li>
#         <a href="c-sharp-tutorial">
#          <img alt="c#" src="https://static.javatpoint.com/images/icon/csharp.png"/>
#          C#
#         </a>
#        </li>
#        <li>
#         <a href="cpp-tutorial">
#          <img alt="c++" src="https://static.javatpoint.com/images/icon/cpp.png"/>
#          C++
#         </a>
#        </li>
#        <li>
#         <a href="data-structure-tutorial">
#          <img alt="data structures" src="https://static.javatpoint.com/images/icon/ds.png"/>
#          DS
#         </a>
#        </li>
#        <li>
#         <a href="https://www.javatpoint.com/aptitude/quantitative">
#          <img alt="aptitude" src="https://static.javatpoint.com/images/icon/aptitude.png"/>
#          Aptitude
#         </a>
#        </li>
#        <li>
#         <a href="reasoning">
#          <img alt="reasoning" src="https://static.javatpoint.com/images/icon/reasoning.png"/>
#          Reasoning
#         </a>
#        </li>
#        <li>
#         <a href="selenium-tutorial">
#          <img alt="selenium" src="https://static.javatpoint.com/images/icon/selenium.png"/>
#          Selenium
#         </a>
#        </li>
#        <li>
#         <a href="dbms-tutorial">
#          <img alt="dbms" src="https://static.javatpoint.com/images/icon/dbms.png"/>
#          DBMS
#         </a>
#        </li>
#        <li>
#         <a href="c-programming-language-tutorial">
#          <img alt="c" src="https://static.javatpoint.com/images/icon/c.png"/>
#          C
#         </a>
#        </li>
#        <li>
#         <a href="android-tutorial">
#          <img alt="android" src="https://static.javatpoint.com/images/icon/android.png"/>
#          Android
#         </a>
#        </li>
#        <li>
#         <a href="interview-questions-and-answers">
#          <img alt="interview questions" src="https://static.javatpoint.com/images/icon/interview.png"/>
#          Interview Q
#         </a>
#        </li>
#       </ul>
#       <br style="clear: left"/>
#      </div>
#     </div>
#     <div class="onlycontent">
#      <div id="city">
#       <table>
#        <tr>
#         <td>
#          <div>
#           <img alt="Youtube" class="lazyload" data-src="https://static.javatpoint.com/images/youtube-32.png" style="vertical-align:middle;"/>
#           <span class="h3" style="vertical-align:middle;font-size:22px">
#            For Videos Join Our Youtube Channel:
#            <a href="https://bit.ly/2FOeX6S" target="_blank">
#             Join Now
#            </a>
#           </span>
#          </div>
#          <hr class="hrhomebox"/>
#          <div style="background-color: #6e9665;color: white;padding: 15px;margin: 10px 0; border-radius: 5px;">
#           <p>
#            <strong>
#             Disclaimer:
#            </strong>
#            This website has no relation with 'Java', it is a free study portal where you can study 200+ technologies. It is an independent online platform created for educational and informational purposes. We don't offer any training or commercial services and will never do in future. We want to make it clear that we are not affiliated with, endorsed by, or connected in any way to Oracle Corporation or the official Java programming language trademark.
#           </p>
#           <p>
#            The term "Java" and its associated logo are registered trademarks of Oracle Corporation. Any reference to Java on this website is made solely for educational purposes, and we do not claim any ownership or partnership with Oracle Corporation.
#           </p>
#          </div>
#          <hr class="hrhomebox"/>
#          <fieldset class="gra1">
#           <h1 class="h3">
#            Latest Tutorials
#           </h1>
#           <div class="firsthomecontent">
#            <a href="https://www.javatpoint.com/splunk">
#             <div class="homecontent">
#              <img alt="Splunk tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/splunk.png"/>
#              <p>
#               Splunk
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/spss">
#             <div class="homecontent">
#              <img alt="SPSS tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/spss.png"/>
#              <p>
#               SPSS
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/swagger">
#             <div class="homecontent">
#              <img alt="Swagger tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/swagger.png"/>
#              <p>
#               Swagger
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/t-sql">
#             <div class="homecontent">
#              <img alt="T-SQL tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/transact-sql.png"/>
#              <p>
#               Transact-SQL
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/tumblr">
#             <div class="homecontent">
#              <img alt="Tumblr tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/tumblr.png"/>
#              <p>
#               Tumblr
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/reactjs-tutorial">
#             <div class="homecontent">
#              <img alt="React tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/react.png"/>
#              <p>
#               ReactJS
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/regex">
#             <div class="homecontent">
#              <img alt="Regex tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/regex.png"/>
#              <p>
#               Regex
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/reinforcement-learning">
#             <div class="homecontent">
#              <img alt="Reinforcement learning tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/react.png"/>
#              <p>
#               Reinforcement Learning
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/r-tutorial">
#             <div class="homecontent">
#              <img alt="R Programming tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/r-programming.png"/>
#              <p>
#               R Programming
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/rxjs">
#             <div class="homecontent">
#              <img alt="RxJS tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/rxjs.png"/>
#              <p>
#               RxJS
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/react-native-tutorial">
#             <div class="homecontent">
#              <img alt="React Native tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/react-native.png"/>
#              <p>
#               React Native
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/python-design-pattern">
#             <div class="homecontent">
#              <img alt="Python Design Patterns" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python-design-patterns.png"/>
#              <p>
#               Python Design Patterns
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/python-pillow">
#             <div class="homecontent">
#              <img alt="Python Pillow tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python-pillow.png"/>
#              <p>
#               Python Pillow
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/python-turtle-programming">
#             <div class="homecontent">
#              <img alt="Python Turtle tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python-turtle.png"/>
#              <p>
#               Python Turtle
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/keras">
#             <div class="homecontent">
#              <img alt="Keras tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/keras.png"/>
#              <p>
#               Keras
#              </p>
#             </div>
#            </a>
#           </div>
#          </fieldset>
#          <hr class="hrhomebox"/>
#          <fieldset class="gra1">
#           <h2 class="h3">
#            Trending Technologies
#           </h2>
#           <div class="firsthomecontent">
#            <a href="https://www.javatpoint.com/artificial-intelligence-ai">
#             <div class="homecontent">
#              <img alt="Artificial Intelligence" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/artificial-intelligence.png"/>
#              <p>
#               Artificial Intelligence
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/aws-tutorial">
#             <div class="homecontent">
#              <img alt="AWS Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/amazon-web-services.png"/>
#              <p>
#               AWS
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/selenium-tutorial">
#             <div class="homecontent">
#              <img alt="Selenium tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/selenium.png"/>
#              <p>
#               Selenium
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/cloud-computing">
#             <div class="homecontent">
#              <img alt="Cloud Computing" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cloud-computing.png"/>
#              <p>
#               Cloud Computing
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/hadoop-tutorial">
#             <div class="homecontent">
#              <img alt="Hadoop tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/hadoop.png"/>
#              <p>
#               Hadoop
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/reactjs-tutorial">
#             <div class="homecontent">
#              <img alt="ReactJS Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/reactjs.png"/>
#              <p>
#               ReactJS
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/data-science">
#             <div class="homecontent">
#              <img alt="Data Science Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/data-science.png"/>
#              <p>
#               Data Science
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/angular-7-tutorial">
#             <div class="homecontent">
#              <img alt="Angular 7 Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/angular7.png"/>
#              <p>
#               Angular 7
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/blockchain-tutorial">
#             <div class="homecontent">
#              <img alt="Blockchain Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/blockchain.png"/>
#              <p>
#               Blockchain
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/git">
#             <div class="homecontent">
#              <img alt="Git Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/git.png"/>
#              <p>
#               Git
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/machine-learning">
#             <div class="homecontent">
#              <img alt="Machine Learning Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/machine-learning.png"/>
#              <p>
#               Machine Learning
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/devops">
#             <div class="homecontent">
#              <img alt="DevOps Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/devops.png"/>
#              <p>
#               DevOps
#              </p>
#             </div>
#            </a>
#           </div>
#          </fieldset>
#          <hr class="hrhomebox"/>
#          <fieldset class="gra1">
#           <h2 class="h3">
#            Preparation
#           </h2>
#           <div class="firsthomecontent">
#            <a href="https://www.javatpoint.com/aptitude/quantitative">
#             <div class="homecontent">
#              <img alt="Aptitude" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/aptitude.png"/>
#              <p>
#               Aptitude
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/reasoning">
#             <div class="homecontent">
#              <img alt="Logical Reasoning" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/reasoning.png"/>
#              <p>
#               Reasoning
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/verbal-ability">
#             <div class="homecontent">
#              <img alt="Verbal Ability" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/verbal-ability.png"/>
#              <p>
#               Verbal Ability
#              </p>
#             </div>
#            </a>
#            <a href="interview-questions-and-answers">
#             <div class="homecontent">
#              <img alt="Interview Questions" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/interview-questions.png"/>
#              <p>
#               Interview Questions
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/company-interview-questions-and-recruitment-process">
#             <div class="homecontent">
#              <img alt="Company Interview Questions" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/company-questions.png"/>
#              <p>
#               Company Questions
#              </p>
#             </div>
#            </a>
#           </div>
#          </fieldset>
#          <hr class="hrhomebox"/>
#          <fieldset class="gra1">
#           <h2 class="h3">
#            B.Tech / MCA
#           </h2>
#           <div class="firsthomecontent">
#            <a href="https://www.javatpoint.com/dbms-tutorial">
#             <div class="homecontent">
#              <img alt="DBMS tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/dbms.png"/>
#              <p>
#               DBMS
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/data-structure-tutorial">
#             <div class="homecontent">
#              <img alt="Data Structures tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/data-structures.png"/>
#              <p>
#               Data Structures
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/daa-tutorial">
#             <div class="homecontent">
#              <img alt="DAA tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/daa.png"/>
#              <p>
#               DAA
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/operating-system">
#             <div class="homecontent">
#              <img alt="Operating System" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/operating-system.png"/>
#              <p>
#               Operating System
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/computer-network-tutorial">
#             <div class="homecontent">
#              <img alt="Computer Network tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/computer-network.png"/>
#              <p>
#               Computer Network
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/compiler-tutorial">
#             <div class="homecontent">
#              <img alt="Compiler Design tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/compiler-design.png"/>
#              <p>
#               Compiler Design
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/computer-organization-and-architecture-tutorial">
#             <div class="homecontent">
#              <img alt="Computer Organization and Architecture" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/computer-organization.png"/>
#              <p>
#               Computer Organization
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/discrete-mathematics-tutorial">
#             <div class="homecontent">
#              <img alt="Discrete Mathematics Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/discrete-mathematics.png"/>
#              <p>
#               Discrete Mathematics
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/ethical-hacking">
#             <div class="homecontent">
#              <img alt="Ethical Hacking Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/ethical-hacking.png"/>
#              <p>
#               Ethical Hacking
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/computer-graphics-tutorial">
#             <div class="homecontent">
#              <img alt="Computer Graphics Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/computer-graphics.png"/>
#              <p>
#               Computer Graphics
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/software-engineering">
#             <div class="homecontent">
#              <img alt="Software Engineering" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/software-engineering.png"/>
#              <p>
#               Software Engineering
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/html-tutorial">
#             <div class="homecontent">
#              <img alt="html tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/web-technology.png"/>
#              <p>
#               Web Technology
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/cyber-security-tutorial">
#             <div class="homecontent">
#              <img alt="Cyber Security tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cyber-security.png"/>
#              <p>
#               Cyber Security
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/automata-tutorial">
#             <div class="homecontent">
#              <img alt="Automata Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/automata.png"/>
#              <p>
#               Automata
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/c-programming-language-tutorial">
#             <div class="homecontent">
#              <img alt="C Language tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/c-programming.png"/>
#              <p>
#               C Programming
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/cpp-tutorial">
#             <div class="homecontent">
#              <img alt="C++ tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cpp.png"/>
#              <p>
#               C++
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/java-tutorial">
#             <div class="homecontent">
#              <img alt="Java tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/new/core-java.png"/>
#              <p>
#               Java
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/net-framework">
#             <div class="homecontent">
#              <img alt=".Net Framework tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/dot-net.png"/>
#              <p>
#               .Net
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/python-tutorial">
#             <div class="homecontent">
#              <img alt="Python tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python.png"/>
#              <p>
#               Python
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/programs-list">
#             <div class="homecontent">
#              <img alt="List of Programs" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/programs.png"/>
#              <p>
#               Programs
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/control-system-tutorial">
#             <div class="homecontent">
#              <img alt="Control Systems tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/control-system.png"/>
#              <p>
#               Control System
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/data-mining">
#             <div class="homecontent">
#              <img alt="Data Mining Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/data-mining.png"/>
#              <p>
#               Data Mining
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/data-warehouse">
#             <div class="homecontent">
#              <img alt="Data Warehouse Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/data-warehouse.png"/>
#              <p>
#               Data Warehouse
#              </p>
#             </div>
#            </a>
#           </div>
#          </fieldset>
#          <hr class="hrhomebox"/>
#          <fieldset class="gra1">
#           <h2 class="h3">
#            Cloud Technologies
#           </h2>
#           <div class="firsthomecontent">
#            <a href="cloud-computing">
#             <div class="homecontent">
#              <img alt="Cloud tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cloud-computing.png"/>
#              <p>
#               Cloud Computing
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/aws-tutorial">
#             <div class="homecontent">
#              <img alt="AWS Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/amazon-web-services.png"/>
#              <p>
#               AWS
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/microsoft-azure">
#             <div class="homecontent">
#              <img alt="Microsoft Azure Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/azure.png"/>
#              <p>
#               Azure
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/salesforce">
#             <div class="homecontent">
#              <img alt="Salesforce Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/salesforce.png"/>
#              <p>
#               Salesforce
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/google-cloud-platform">
#             <div class="homecontent">
#              <img alt="Google Cloud Platform Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/google-cloud-platform.png"/>
#              <p>
#               Google Cloud
#              </p>
#             </div>
#            </a>
#           </div>
#          </fieldset>
#          <hr class="hrhomebox"/>
#          <fieldset class="gra1">
#           <h2 class="h3">
#            Testing Tutorials
#           </h2>
#           <div class="firsthomecontent">
#            <a href="https://www.javatpoint.com/software-testing-tutorial">
#             <div class="homecontent">
#              <img alt="Software Testing Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/software-testing.png"/>
#              <p>
#               Software Testing
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/selenium-tutorial">
#             <div class="homecontent">
#              <img alt="Selenium tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/selenium.png"/>
#              <p>
#               Selenium
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/agile">
#             <div class="homecontent">
#              <img alt="Agile Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/agile.png"/>
#              <p>
#               Agile
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/jira-tutorial">
#             <div class="homecontent">
#              <img alt="JIRA Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jira.png"/>
#              <p>
#               JIRA
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/bugzilla">
#             <div class="homecontent">
#              <img alt="Bugzilla Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/bugzilla.png"/>
#              <p>
#               Bugzilla
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/etl-testing">
#             <div class="homecontent">
#              <img alt="ETL Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/etl.png"/>
#              <p>
#               ETL
#              </p>
#             </div>
#            </a>
#            <a href="jmeter-tutorial">
#             <div class="homecontent">
#              <img alt="JMeter tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jmeter.png"/>
#              <p>
#               JMeter
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/quality-assurance">
#             <div class="homecontent">
#              <img alt="quality assurance Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/quality-assurance.png"/>
#              <p>
#               QA
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/testng-tutorial">
#             <div class="homecontent">
#              <img alt="TestNG Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/new/testng.png"/>
#              <p>
#               TestNG
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/automation-anywhere">
#             <div class="homecontent">
#              <img alt="Automation Anywhere Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/automation-anywhere.png"/>
#              <p>
#               Automation Anywhere
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/uipath">
#             <div class="homecontent">
#              <img alt="UiPath Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/uipath.png"/>
#              <p>
#               UiPath
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/selenium-python">
#             <div class="homecontent">
#              <img alt="Selenium Python" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/selenium-python.png"/>
#              <p>
#               Selenium Python
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/postman">
#             <div class="homecontent">
#              <img alt="Postman Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/postman.png"/>
#              <p>
#               Postman
#              </p>
#             </div>
#            </a>
#            <a href="junit-tutorial">
#             <div class="homecontent">
#              <img alt="JUnit tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/junit.png"/>
#              <p>
#               Junit
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/soapui">
#             <div class="homecontent">
#              <img alt="SoapUI tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/soapui.png"/>
#              <p>
#               SoapUI
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/rpa">
#             <div class="homecontent">
#              <img alt="RPA tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/rpa.png"/>
#              <p>
#               RPA
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/manual-testing">
#             <div class="homecontent">
#              <img alt="manual testing tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/manual-testing.png"/>
#              <p>
#               Manual Testing
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/cucumber-testing">
#             <div class="homecontent">
#              <img alt="cucumber tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/cucumber.png"/>
#              <p>
#               Cucumber
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/appium">
#             <div class="homecontent">
#              <img alt="Appium tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/appium.png"/>
#              <p>
#               Appium
#              </p>
#             </div>
#            </a>
#           </div>
#          </fieldset>
#          <hr class="hrhomebox"/>
#          <fieldset class="gra1">
#           <h2 class="h3">
#            Python Tutorials
#           </h2>
#           <div class="firsthomecontent">
#            <a href="python-tutorial">
#             <div class="homecontent">
#              <img alt="Python tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/python.png"/>
#              <p>
#               Python
#              </p>
#             </div>
#            </a>
#            <a href="django-tutorial">
#             <div class="homecontent">
#              <img alt="django tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/django.png"/>
#              <p>
#               Django
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/flask-tutorial">
#             <div class="homecontent">
#              <img alt="Flask Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/flask.png"/>
#              <p>
#               Flask
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/numpy-tutorial">
#             <div class="homecontent">
#              <img alt="Numpy Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/numpy.png"/>
#              <p>
#               NumPy
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/python-tkinter">
#             <div class="homecontent">
#              <img alt="Python Tkinter Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/tkinter.png"/>
#              <p>
#               Tkinter
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/pytorch">
#             <div class="homecontent">
#              <img alt="Pytorch Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/pytorch.png"/>
#              <p>
#               Pytorch
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/pygame">
#             <div class="homecontent">
#              <img alt="Pygame Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/pygame.png"/>
#              <p>
#               Pygame
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/python-scipy">
#             <div class="homecontent">
#              <img alt="Python Scipy Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/scipy.png"/>
#              <p>
#               Scipy
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/python-pandas">
#             <div class="homecontent">
#              <img alt="Pandas Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/pandas.png"/>
#              <p>
#               Pandas
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/opencv">
#             <div class="homecontent">
#              <img alt="OpenCV Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/opencv.png"/>
#              <p>
#               OpenCV
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/matplotlib">
#             <div class="homecontent">
#              <img alt="Matplotlib Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/matplotlib.png"/>
#              <p>
#               Matplotlib
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/python-openpyxl">
#             <div class="homecontent">
#              <img alt="Openpyxl Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/openpyxl.png"/>
#              <p>
#               Openpyxl
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/selenium-python">
#             <div class="homecontent">
#              <img alt="Selenium Python" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/selenium-python.png"/>
#              <p>
#               Selenium Python
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/kivy">
#             <div class="homecontent">
#              <img alt="Kivy Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/kivy.png"/>
#              <p>
#               Kivy
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/jupyter-notebook">
#             <div class="homecontent">
#              <img alt="Jupyter Notebook Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jupyter.png"/>
#              <p>
#               Jupyter
#              </p>
#             </div>
#            </a>
#           </div>
#          </fieldset>
#          <hr class="hrhomebox"/>
#          <fieldset class="gra1">
#           <h2 class="h3">
#            Java Technology
#           </h2>
#           <div class="firsthomecontent">
#            <a href="java-tutorial">
#             <div class="homecontent">
#              <img alt="Core Java tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/new/core-java.png"/>
#              <p>
#               Java
#              </p>
#             </div>
#            </a>
#            <a href="servlet-tutorial">
#             <div class="homecontent">
#              <img alt="Java Servlet tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/new/servlet.png"/>
#              <p>
#               Servlet
#              </p>
#             </div>
#            </a>
#            <a href="jsp-tutorial">
#             <div class="homecontent">
#              <img alt="Java JSP tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jsp.png"/>
#              <p>
#               JSP
#              </p>
#             </div>
#            </a>
#            <a href="spring-boot-tutorial">
#             <div class="homecontent">
#              <img alt="Spring Boot tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/spring-boot.png"/>
#              <p>
#               Spring Boot
#              </p>
#             </div>
#            </a>
#            <a href="spring-tutorial">
#             <div class="homecontent">
#              <img alt="Spring framework tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/spring.png"/>
#              <p>
#               Spring Framework
#              </p>
#             </div>
#            </a>
#            <a href="hibernate-tutorial">
#             <div class="homecontent">
#              <img alt="Hibernate tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/hibernate.png"/>
#              <p>
#               Hibernate
#              </p>
#             </div>
#            </a>
#            <a href="design-patterns-in-java">
#             <div class="homecontent">
#              <img alt="Java Design Pattern tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/new/design-patterns.png"/>
#              <p>
#               Design Patterns
#              </p>
#             </div>
#            </a>
#            <a href="java-web-services-tutorial">
#             <div class="homecontent">
#              <img alt="Java Web Services tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/java-ws.png"/>
#              <p>
#               Java Web Services
#              </p>
#             </div>
#            </a>
#            <a href="struts-2-tutorial">
#             <div class="homecontent">
#              <img alt="Struts tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/struts.png"/>
#              <p>
#               Struts
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/restful-web-services-tutorial">
#             <div class="homecontent">
#              <img alt="Restful Web Services Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/restful.png"/>
#              <p>
#               RESTful Web Services
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/microservices">
#             <div class="homecontent">
#              <img alt="Microservices Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/microservices.png"/>
#              <p>
#               Microservices
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/spring-cloud">
#             <div class="homecontent">
#              <img alt="Spring Cloud Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/spring-cloud.png"/>
#              <p>
#               Spring Cloud
#              </p>
#             </div>
#            </a>
#            <a href="https://www.javatpoint.com/jenkins">
#             <div class="homecontent">
#              <img alt="Jenkins Tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/jenkins.png"/>
#              <p>
#               Jenkins
#              </p>
#             </div>
#            </a>
#            <a href="java-swing">
#             <div class="homecontent">
#              <img alt="Java Swing tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/new/java-swing.png"/>
#              <p>
#               Java Swing
#              </p>
#             </div>
#            </a>
#            <a href="javafx-tutorial">
#             <div class="homecontent">
#              <img alt="javafx tutorial" class="lazyload" data-src="https://static.javatpoint.com/images/homeicon/new/java-fx.png"/>
#              <p>
#               JavaFX
#              </p>
#             </div>
#            </a>
#            <a href="maven-tutorial">
# ...
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-validity-and-reliability">
#         22nd Jun - Difference Between Validity and Reliability
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-subungual-hematoma-and-melanoma">
#         22nd Jun - Difference Between Subungual Hematoma and Melanoma
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-social-science-and-humanities">
#         22nd Jun - Difference Between Social Science And Humanities
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-travel-and-tourism">
#         22nd Jun - Difference Between Travel and Tourism
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-value-proposition-and-marketing-offer">
#         22nd Jun - Difference Between Value Proposition and Marketing Offer
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-vowels-and-consonants">
#         22nd Jun - Difference Between Vowels and Consonants
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-warm-and-cool-blonde">
#         22nd Jun - Difference between Warm and Cool Blonde
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-trab-and-tsi-test">
#         22nd Jun - Difference between TRAb and TSI Test
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-unilateral-and-bilateral-contracts">
#         22nd Jun - Difference Between Unilateral and Bilateral Contracts
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-transitive-and-intransitive-verbs">
#         22nd Jun - Difference Between Transitive and Intransitive Verbs
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-acquittal-and-discharge">
#         22nd Jun - Difference Between Acquittal and Discharge
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-across-and-through">
#         22nd Jun - Difference Between Across and Through
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-investigation-and-inquiry">
#         22nd Jun - Difference Between Investigation and Inquiry
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-marginal-analysis-and-break-even-analysis">
#         22nd Jun - Difference Between Marginal Analysis and Break-even Analysis
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-master-budget-and-cash-budget">
#         22nd Jun - Difference Between Master Budget and Cash Budget
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-product-positioning-and-brand-positioning">
#         22nd Jun - Difference Between Product Positioning and Brand Positioning
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-monetary-and-non-monetary-asset">
#         22nd Jun - Difference Between Monetary and Non-Monetary Asset
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-social-media-marketing-and-digital-marketing">
#         22nd Jun - Difference Between Social Media Marketing and Digital Marketing
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-active-and-passive-learning">
#         22nd Jun - Difference Between Active and Passive Learning
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-active-listening-and-passive-listening">
#         22nd Jun - Difference Between Active Listening and Passive Listening
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-alliance-and-coalition">
#         22nd Jun - Difference Between Alliance And Coalition
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-physical-capital-and-human-capital">
#         22nd Jun - Difference Between Physical Capital and Human Capital
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-upselling-and-cross-selling">
#         22nd Jun - Difference Between Upselling and Cross-selling
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-unipolar-and-bipolar-world">
#         22nd Jun - Difference Between Unipolar and Bipolar World
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-tax-planning-and-tax-avoidance">
#         22nd Jun - Difference between Tax Planning and Tax Avoidance
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-peer-pressure-and-peer-influence">
#         22nd Jun - Difference Between Peer Pressure and Peer Influence
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-options-and-swaps">
#         22nd Jun - Difference Between Options and Swaps
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-laws-and-ethics">
#         22nd Jun - Difference between Laws and Ethics
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-economic-and-social-infrastructure">
#         22nd Jun - Difference Between Economic and Social Infrastructure
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-content-writing-and-copy-writing">
#         22nd Jun - Difference Between Content Writing and Copy Writing
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-by-product-and-waste">
#         22nd Jun - Difference Between By Product and Waste
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-deduction-and-exemption">
#         22nd Jun - Difference between Deduction and Exemption
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-market-economy-and-command-economy">
#         22nd Jun - Difference between Market Economy and Command Economy
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-optimism-and-pessimism">
#         22nd Jun - Difference between Optimism and Pessimism
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-article-and-essay">
#         22nd Jun - Difference Between Article and Essay
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-whole-life-and-term-life-insurance">
#         22nd Jun - Difference Between Whole Life and Term Life Insurance
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-translation-and-remeasurement">
#         22nd Jun - Difference Between Translation and Remeasurement
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-orientation-and-onboarding">
#         22nd Jun - Difference between Orientation and Onboarding
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-proportionate-consolidation-and-equity-method">
#         22nd Jun - Difference between Proportionate Consolidation and Equity Method
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-hedging-and-forward-contract">
#         22nd Jun - Difference between Hedging and Forward Contract
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-historical-cost-and-fair-value">
#         22nd Jun - Difference Between Historical Cost And Fair Value
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-line-organization-and-functional-organization">
#         22nd Jun - Difference Between Line Organization And Functional Organization
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-matrix-and-functional-structure">
#         22nd Jun - Difference Between Matrix and Functional Structure
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-rules-and-norms">
#         22nd Jun - Difference Between Rules and Norms
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-rules-and-standards">
#         22nd Jun - Difference between Rules and Standards
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-servant-leadership-and-transformational-leadership">
#         22nd Jun - Difference Between Servant Leadership and Transformational Leadership
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-tax-deduction-and-tax-credits">
#         22nd Jun - Difference between Tax Deduction and Tax Credits
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-present-value-and-net-present-value">
#         22nd Jun - Difference Between Present Value And Net Present Value
#        </a>
#       </li>
#       <li>
#        <a href="mongodb-vs-nosql">
#         22nd Jun - MongoDB vs NoSQL
#        </a>
#       </li>
#       <li>
#        <a href="oracle-vs-sql">
#         22nd Jun - Oracle vs SQL
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-airedale-and-welsh-terrier">
#         22nd Jun - Difference Between Airedale And Welsh Terrier
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-annuity-and-perpetuity">
#         22nd Jun - Difference Between Annuity and Perpetuity
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-apr-and-note-rate">
#         22nd Jun - Difference Between APR and Note Rate
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-bloating-and-distension">
#         22nd Jun - Difference Between Bloating and Distension
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-consumer-market-and-business-market">
#         22nd Jun - Difference Between Consumer Market and Business Market
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-eva-and-roi">
#         22nd Jun - Difference Between EVA And ROI
#        </a>
#       </li>
#       <li>
#        <a href="difference-between-functional-and-divisional-structure">
#         22nd Jun - Difference Between Functional and Divisional Structure
#        </a>
#       </li>
#       <br/>
#       <br/>
#      </ol>
#     </div>
#     <div class="right1024" style="float:left;margin-left:10px;margin-top:10px;">
#     </div>
#     <div id="footer" style="clear:both;width:100%;">
#      <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#      </script>
#      <script>
#       var _gaq=_gaq || []; _gaq.push(['_setAccount', 'UA-24880427-1']); _gaq.push(['_trackPageview']); (function(){var ga=document.createElement('script'); ga.type='text/javascript'; ga.async=true; ga.src=('https:'==document.location.protocol ? 'https://ssl' : 'https://www') + '.google-analytics.com/ga.js'; var s=document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);})();
#      </script>
#      <div style="margin-top:5px;text-align:center">
#       <sup style="font:16px arial;">
#        Like/Subscribe us for latest updates or newsletter
#       </sup>
#       <a href="https://feeds.feedburner.com/javatpointsonoo" rel="nofollow noopener" target="_blank">
#        <img alt="RSS Feed" src="https://static.javatpoint.com/images/social/rss1.png"/>
#       </a>
#       <a href="https://feedburner.google.com/fb/a/mailverify?uri=javatpointsonoo" rel="nofollow noopener" target="_blank">
#        <img alt="Subscribe to Get Email Alerts" src="https://static.javatpoint.com/images/social/mail1.png"/>
#       </a>
#       <a href="https://www.facebook.com/javatpoint" rel="nofollow noopener" target="_blank">
#        <img alt="Facebook Page" src="https://static.javatpoint.com/images/social/facebook1.jpg"/>
#       </a>
#       <a href="https://twitter.com/pagejavatpoint" rel="nofollow" target="_blank noopener">
#        <img alt="Twitter Page" src="https://static.javatpoint.com/images/social/twitter1.png"/>
#       </a>
#       <a href="https://www.youtube.com/channel/UCUnYvQVCrJoFWZhKK3O2xLg" rel="nofollow noopener" target="_blank">
#        <img alt="YouTube" src="https://static.javatpoint.com/images/youtube32.png"/>
#       </a>
#       <a href="https://javatpoint.blogspot.com" rel="nofollow noopener" target="_blank">
#        <img alt="Blog Page" src="https://static.javatpoint.com/images/social/blog.png"/>
#       </a>
#      </div>
#      <footer class="footer1">
#       <div class="column4">
#        <h3>
#         Learn Tutorials
#        </h3>
#        <a href="https://www.javatpoint.com/java-tutorial">
#         Learn Java
#        </a>
#        <a href="https://www.javatpoint.com/data-structure-tutorial">
#         Learn Data Structures
#        </a>
#        <a href="https://www.javatpoint.com/c-programming-language-tutorial">
#         Learn C Programming
#        </a>
#        <a href="https://www.javatpoint.com/cpp-tutorial">
#         Learn C++ Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/c-sharp-tutorial">
#         Learn C# Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/php-tutorial">
#         Learn PHP Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/html-tutorial">
#         Learn HTML Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/javascript-tutorial">
#         Learn JavaScript Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/jquery-tutorial">
#         Learn jQuery Tutorial
#        </a>
#        <a href="https://www.javatpoint.com/spring-tutorial">
#         Learn Spring Tutorial
#        </a>
#       </div>
#       <div class="column4">
#        <h3>
#         Interview Questions
#        </h3>
#        <a href="corejava-interview-questions">
#         Java Interview Questions
#        </a>
#        <a href="sql-interview-questions">
#         SQL Interview Questions
#        </a>
#        <a href="python-interview-questions">
#         Python Interview Questions
#        </a>
#        <a href="javascript-interview-questions">
#         JavaScript Interview Questions
#        </a>
#        <a href="top-angular-interview-questions">
#         Angular Interview Questions
#        </a>
#        <a href="selenium-interview-questions">
#         Selenium Interview Questions
#        </a>
#        <a href="spring-boot-interview-questions">
#         Spring Boot Interview Questions
#        </a>
#        <a href="job-interview-questions">
#         HR Interview Questions
#        </a>
#        <a href="cpp-interview-questions">
#         C++ Interview Questions
#        </a>
#        <a href="data-structure-interview-questions">
#         Data Structure Interview Questions
#        </a>
#       </div>
#       <div class="column4">
#        <h3>
#         About
#        </h3>
#        <p>
#         This website is developed to help students on various technologies such as Artificial Intelligence, Machine Learning, C, C++, Python, Java, PHP, HTML, CSS, JavaScript, jQuery, ReactJS, Node.js, AngularJS, Bootstrap, XML, SQL, PL/SQL, MySQL etc.
#        </p>
#        <p>
#         This website provides tutorials with examples, code snippets, and practical insights, making it suitable for both beginners and experienced developers.
#        </p>
#        <p>
#         There are also many interview questions which will help students to get placed in the companies.
#        </p>
#       </div>
#       <div class="column4">
#        <h3>
#         Contact
#        </h3>
#        <a href="https://www.javatpoint.com/contact-us">
#         Contact Us
#        </a>
#        <a href="https://www.javatpoint.com/privacy-policy">
#         Privacy Policy
#        </a>
#        <a href="https://www.javatpoint.com/sitemap.xml">
#         Sitemap
#        </a>
#        <br/>
#        <a href="https://www.javatpoint.com/sonoo-jaiswal">
#         About Me
#        </a>
#       </div>
#      </footer>
#      <footer class="footer2">
#       <p>
#        © Copyright 2011-2021 www.javatpoint.com. All rights reserved. Developed by Tpoint Tech.
#       </p>
#      </footer>
#      <div id="bot-root">
#      </div>
#      <script>
#       (function() { var e = document.createElement('script'); e.src = 'https://app.pushbrothers.com/js/notification-bot.js?cnfg=a3cc04a1-8471-450e-b01e-c9d752b16eb0'; document.getElementById('bot-root').appendChild(e);}());
#      </script>
#     </div>
#    </div>
#   </div>
#   <script src="https://static.javatpoint.com/js/shcoreandbrush.js">
#   </script>
#   <script>
#    dp.SyntaxHighlighter.HighlightAll('code');
#   </script>
#   <script async="" src="https://static.javatpoint.com/lazysizes.min.js">
#   </script>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-BMVLE5WY82">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-BMVLE5WY82');
#   </script>
#  </body>
# </html>

# %%
print(soup.title)
# Out:
# <title>Tutorials List - Javatpoint</title>

# %%
print(soup.title.text)
# Out:
# Tutorials List - Javatpoint

# %%
for link in soup.find_all("a"):  
  print("Inner Text is: {}".format(link.text))  
  print("Title is: {}".format(link.get("title")))  
  print("href is: {}".format(link.get("href")))
# Out:
# Inner Text is:
# Title is: None
# href is: https://www.javatpoint.com
# Inner Text is:
# Title is: None
# href is: https://www.javatpoint.com
# Inner Text is:  Home
# Title is: None
# href is: https://www.javatpoint.com
# Inner Text is:  Python
# Title is: None
# href is: python-tutorial
# Inner Text is:  Java
# Title is: None
# href is: java-tutorial
# Inner Text is:  JavaScript
# Title is: None
# href is: javascript-tutorial
# Inner Text is:  HTML
# Title is: None
# href is: html-tutorial
# Inner Text is:  SQL
# Title is: None
# href is: sql-tutorial
# Inner Text is:  PHP
# Title is: None
# href is: php-tutorial
# Inner Text is:  C#
# Title is: None
# href is: c-sharp-tutorial
# Inner Text is:  C++
# Title is: None
# href is: cpp-tutorial
# Inner Text is:  DS
# Title is: None
# href is: data-structure-tutorial
# Inner Text is:  Aptitude
# Title is: None
# href is: https://www.javatpoint.com/aptitude/quantitative
# Inner Text is:  Reasoning
# Title is: None
# href is: reasoning
# Inner Text is:  Selenium
# Title is: None
# href is: selenium-tutorial
# Inner Text is:  DBMS
# Title is: None
# href is: dbms-tutorial
# Inner Text is:  C
# Title is: None
# href is: c-programming-language-tutorial
# Inner Text is:  Android
# Title is: None
# href is: android-tutorial
# Inner Text is:  Interview Q
# Title is: None
# href is: interview-questions-and-answers
# Inner Text is:  Join Now
# Title is: None
# href is: https://bit.ly/2FOeX6S
# Inner Text is:
#
# Splunk
#
#
# Title is: None
# href is: https://www.javatpoint.com/splunk
# Inner Text is:
#
# SPSS
#
#
# Title is: None
# href is: https://www.javatpoint.com/spss
# Inner Text is:
#
# Swagger
#
#
# Title is: None
# href is: https://www.javatpoint.com/swagger
# Inner Text is:
#
# Transact-SQL
#
#
# Title is: None
# href is: https://www.javatpoint.com/t-sql
# Inner Text is:
#
# Tumblr
#
#
# Title is: None
# href is: https://www.javatpoint.com/tumblr
# Inner Text is:
#
# ReactJS
#
#
# Title is: None
# href is: https://www.javatpoint.com/reactjs-tutorial
# Inner Text is:
#
# Regex
#
#
# Title is: None
# href is: https://www.javatpoint.com/regex
# Inner Text is:
#
# Reinforcement Learning
#
#
# Title is: None
# href is: https://www.javatpoint.com/reinforcement-learning
# Inner Text is:
#
# R Programming
#
#
# Title is: None
# href is: https://www.javatpoint.com/r-tutorial
# Inner Text is:
#
# RxJS
#
#
# Title is: None
# href is: https://www.javatpoint.com/rxjs
# Inner Text is:
#
# React Native
#
#
# Title is: None
# href is: https://www.javatpoint.com/react-native-tutorial
# Inner Text is:
#
# Python Design Patterns
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-design-pattern
# Inner Text is:
#
# Python Pillow
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-pillow
# Inner Text is:
#
# Python Turtle
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-turtle-programming
# Inner Text is:
#
# Keras
#
#
# Title is: None
# href is: https://www.javatpoint.com/keras
# Inner Text is:
#
# Artificial Intelligence
#
#
# Title is: None
# href is: https://www.javatpoint.com/artificial-intelligence-ai
# Inner Text is:
#
# AWS
#
#
# Title is: None
# href is: https://www.javatpoint.com/aws-tutorial
# Inner Text is:
#
# Selenium
#
#
# Title is: None
# href is: https://www.javatpoint.com/selenium-tutorial
# Inner Text is:
#
# Cloud Computing
#
#
# Title is: None
# href is: https://www.javatpoint.com/cloud-computing
# Inner Text is:
#
# Hadoop
#
#
# Title is: None
# href is: https://www.javatpoint.com/hadoop-tutorial
# Inner Text is:
#
# ReactJS
#
#
# Title is: None
# href is: https://www.javatpoint.com/reactjs-tutorial
# Inner Text is:
#
# Data Science
#
#
# Title is: None
# href is: https://www.javatpoint.com/data-science
# Inner Text is:
#
# Angular 7
#
#
# Title is: None
# href is: https://www.javatpoint.com/angular-7-tutorial
# Inner Text is:
#
# Blockchain
#
#
# Title is: None
# href is: https://www.javatpoint.com/blockchain-tutorial
# Inner Text is:
#
# Git
#
#
# Title is: None
# href is: https://www.javatpoint.com/git
# Inner Text is:
#
# Machine Learning
#
#
# Title is: None
# href is: https://www.javatpoint.com/machine-learning
# Inner Text is:
#
# DevOps
#
#
# Title is: None
# href is: https://www.javatpoint.com/devops
# Inner Text is:
#
# Aptitude
#
#
# Title is: None
# href is: https://www.javatpoint.com/aptitude/quantitative
# Inner Text is:
#
# Reasoning
#
#
# Title is: None
# href is: https://www.javatpoint.com/reasoning
# Inner Text is:
#
# Verbal Ability
#
#
# Title is: None
# href is: https://www.javatpoint.com/verbal-ability
# Inner Text is:
#
# Interview Questions
#
#
# Title is: None
# href is: interview-questions-and-answers
# Inner Text is:
#
# Company Questions
#
#
# Title is: None
# href is: https://www.javatpoint.com/company-interview-questions-and-recruitment-process
# Inner Text is:
#
# DBMS
#
#
# Title is: None
# href is: https://www.javatpoint.com/dbms-tutorial
# Inner Text is:
#
# Data Structures
#
#
# Title is: None
# href is: https://www.javatpoint.com/data-structure-tutorial
# Inner Text is:
#
# DAA
#
#
# Title is: None
# href is: https://www.javatpoint.com/daa-tutorial
# Inner Text is:
#
# Operating System
#
#
# Title is: None
# href is: https://www.javatpoint.com/operating-system
# Inner Text is:
#
# Computer Network
#
#
# Title is: None
# href is: https://www.javatpoint.com/computer-network-tutorial
# Inner Text is:
#
# Compiler Design
#
#
# Title is: None
# href is: https://www.javatpoint.com/compiler-tutorial
# Inner Text is:
#
# Computer Organization
#
#
# Title is: None
# href is: https://www.javatpoint.com/computer-organization-and-architecture-tutorial
# Inner Text is:
#
# Discrete Mathematics
#
#
# Title is: None
# href is: https://www.javatpoint.com/discrete-mathematics-tutorial
# Inner Text is:
#
# Ethical Hacking
#
#
# Title is: None
# href is: https://www.javatpoint.com/ethical-hacking
# Inner Text is:
#
# Computer Graphics
#
#
# Title is: None
# href is: https://www.javatpoint.com/computer-graphics-tutorial
# Inner Text is:
#
# Software Engineering
#
#
# Title is: None
# href is: https://www.javatpoint.com/software-engineering
# Inner Text is:
#
# Web Technology
#
#
# Title is: None
# href is: https://www.javatpoint.com/html-tutorial
# Inner Text is:
#
# Cyber Security
#
#
# Title is: None
# href is: https://www.javatpoint.com/cyber-security-tutorial
# Inner Text is:
#
# Automata
#
#
# Title is: None
# href is: https://www.javatpoint.com/automata-tutorial
# Inner Text is:
#
# C Programming
#
#
# Title is: None
# href is: https://www.javatpoint.com/c-programming-language-tutorial
# Inner Text is:
#
# C++
#
#
# Title is: None
# href is: https://www.javatpoint.com/cpp-tutorial
# Inner Text is:
#
# Java
#
#
# Title is: None
# href is: https://www.javatpoint.com/java-tutorial
# Inner Text is:
#
# .Net
#
#
# Title is: None
# href is: https://www.javatpoint.com/net-framework
# Inner Text is:
#
# Python
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-tutorial
# Inner Text is:
#
# Programs
#
#
# Title is: None
# href is: https://www.javatpoint.com/programs-list
# Inner Text is:
#
# Control System
#
#
# Title is: None
# href is: https://www.javatpoint.com/control-system-tutorial
# Inner Text is:
#
# Data Mining
#
#
# Title is: None
# href is: https://www.javatpoint.com/data-mining
# Inner Text is:
#
# Data Warehouse
#
#
# Title is: None
# href is: https://www.javatpoint.com/data-warehouse
# Inner Text is:
#
# Cloud Computing
#
#
# Title is: None
# href is: cloud-computing
# Inner Text is:
#
# AWS
#
#
# Title is: None
# href is: https://www.javatpoint.com/aws-tutorial
# Inner Text is:
#
# Azure
#
#
# Title is: None
# href is: https://www.javatpoint.com/microsoft-azure
# Inner Text is:
#
# Salesforce
#
#
# Title is: None
# href is: https://www.javatpoint.com/salesforce
# Inner Text is:
#
# Google Cloud
#
#
# Title is: None
# href is: https://www.javatpoint.com/google-cloud-platform
# Inner Text is:
#
# Software Testing
#
#
# Title is: None
# href is: https://www.javatpoint.com/software-testing-tutorial
# Inner Text is:
#
# Selenium
#
#
# Title is: None
# href is: https://www.javatpoint.com/selenium-tutorial
# Inner Text is:
#
# Agile
#
#
# Title is: None
# href is: https://www.javatpoint.com/agile
# Inner Text is:
#
# JIRA
#
#
# Title is: None
# href is: https://www.javatpoint.com/jira-tutorial
# Inner Text is:
#
# Bugzilla
#
#
# Title is: None
# href is: https://www.javatpoint.com/bugzilla
# Inner Text is:
#
# ETL
#
#
# Title is: None
# href is: https://www.javatpoint.com/etl-testing
# Inner Text is:
#
# JMeter
#
#
# Title is: None
# href is: jmeter-tutorial
# Inner Text is:
#
# QA
#
#
# Title is: None
# href is: https://www.javatpoint.com/quality-assurance
# Inner Text is:
#
# TestNG
#
#
# Title is: None
# href is: https://www.javatpoint.com/testng-tutorial
# Inner Text is:
#
# Automation Anywhere
#
#
# Title is: None
# href is: https://www.javatpoint.com/automation-anywhere
# Inner Text is:
#
# UiPath
#
#
# Title is: None
# href is: https://www.javatpoint.com/uipath
# Inner Text is:
#
# Selenium Python
#
#
# Title is: None
# href is: https://www.javatpoint.com/selenium-python
# Inner Text is:
#
# Postman
#
#
# Title is: None
# href is: https://www.javatpoint.com/postman
# Inner Text is:
#
# Junit
#
#
# Title is: None
# href is: junit-tutorial
# Inner Text is:
#
# SoapUI
#
#
# Title is: None
# href is: https://www.javatpoint.com/soapui
# Inner Text is:
#
# RPA
#
#
# Title is: None
# href is: https://www.javatpoint.com/rpa
# Inner Text is:
#
# Manual Testing
#
#
# Title is: None
# href is: https://www.javatpoint.com/manual-testing
# Inner Text is:
#
# Cucumber
#
#
# Title is: None
# href is: https://www.javatpoint.com/cucumber-testing
# Inner Text is:
#
# Appium
#
#
# Title is: None
# href is: https://www.javatpoint.com/appium
# Inner Text is:
#
# Python
#
#
# Title is: None
# href is: python-tutorial
# Inner Text is:
#
# Django
#
#
# Title is: None
# href is: django-tutorial
# Inner Text is:
#
# Flask
#
#
# Title is: None
# href is: https://www.javatpoint.com/flask-tutorial
# Inner Text is:
#
# NumPy
#
#
# Title is: None
# href is: https://www.javatpoint.com/numpy-tutorial
# Inner Text is:
#
# Tkinter
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-tkinter
# Inner Text is:
#
# Pytorch
#
#
# Title is: None
# href is: https://www.javatpoint.com/pytorch
# Inner Text is:
#
# Pygame
#
#
# Title is: None
# href is: https://www.javatpoint.com/pygame
# Inner Text is:
#
# Scipy
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-scipy
# Inner Text is:
#
# Pandas
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-pandas
# Inner Text is:
#
# OpenCV
#
#
# Title is: None
# href is: https://www.javatpoint.com/opencv
# Inner Text is:
#
# Matplotlib
#
#
# Title is: None
# href is: https://www.javatpoint.com/matplotlib
# Inner Text is:
#
# Openpyxl
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-openpyxl
# Inner Text is:
#
# Selenium Python
#
#
# Title is: None
# href is: https://www.javatpoint.com/selenium-python
# Inner Text is:
#
# Kivy
#
#
# Title is: None
# href is: https://www.javatpoint.com/kivy
# Inner Text is:
#
# Jupyter
#
#
# Title is: None
# href is: https://www.javatpoint.com/jupyter-notebook
# Inner Text is:
#
# Java
#
#
# Title is: None
# href is: java-tutorial
# Inner Text is:
#
# Servlet
#
#
# Title is: None
# href is: servlet-tutorial
# Inner Text is:
#
# JSP
#
#
# Title is: None
# href is: jsp-tutorial
# Inner Text is:
#
# Spring Boot
#
#
# Title is: None
# href is: spring-boot-tutorial
# Inner Text is:
#
# Spring Framework
#
#
# Title is: None
# href is: spring-tutorial
# Inner Text is:
#
# Hibernate
#
#
# Title is: None
# href is: hibernate-tutorial
# Inner Text is:
#
# Design Patterns
#
#
# Title is: None
# href is: design-patterns-in-java
# Inner Text is:
#
# Java Web Services
#
#
# Title is: None
# href is: java-web-services-tutorial
# Inner Text is:
#
# Struts
#
#
# Title is: None
# href is: struts-2-tutorial
# Inner Text is:
#
# RESTful Web Services
#
#
# Title is: None
# href is: https://www.javatpoint.com/restful-web-services-tutorial
# Inner Text is:
#
# Microservices
#
#
# Title is: None
# href is: https://www.javatpoint.com/microservices
# Inner Text is:
#
# Spring Cloud
#
#
# Title is: None
# href is: https://www.javatpoint.com/spring-cloud
# Inner Text is:
#
# Jenkins
#
#
# Title is: None
# href is: https://www.javatpoint.com/jenkins
# Inner Text is:
#
# Java Swing
#
#
# Title is: None
# href is: java-swing
# Inner Text is:
#
# JavaFX
#
#
# Title is: None
# href is: javafx-tutorial
# Inner Text is:
#
# Maven
#
#
# Title is: None
# href is: maven-tutorial
# Inner Text is:
#
# Apache POI
#
#
# Title is: None
# href is: apache-poi-tutorial
# Inner Text is:
#
# JSF
#
#
# Title is: None
# href is: jsf-tutorial
# Inner Text is:
#
# EJB
#
#
# Title is: None
# href is: ejb-tutorial
# Inner Text is:
#
# JSTL
#
#
# Title is: None
# href is: jstl
# Inner Text is:
#
# Primefaces
#
#
# Title is: None
# href is: primefaces-tutorial
# Inner Text is:
#
# JDB
#
#
# Title is: None
# href is: jdb-tutorial
# Inner Text is:
#
# Apache Ant
#
#
# Title is: None
# href is: apache-ant-tutorial
# Inner Text is:
#
# JPA
#
#
# Title is: None
# href is: jpa-tutorial
# Inner Text is:
#
# Java Mail
#
#
# Title is: None
# href is: java-mail-api-tutorial
# Inner Text is:
#
# Jsoup
#
#
# Title is: None
# href is: jsoup-tutorial
# Inner Text is:
#
# JAXB
#
#
# Title is: None
# href is: jaxb-tutorial
# Inner Text is:
#
# Java I/O
#
#
# Title is: None
# href is: java-io
# Inner Text is:
#
# Java AWT
#
#
# Title is: None
# href is: java-awt
# Inner Text is:
#
# Collections
#
#
# Title is: None
# href is: collections-in-java
# Inner Text is:
#
# Java Date
#
#
# Title is: None
# href is: java-date
# Inner Text is:
#
# RichFaces
#
#
# Title is: None
# href is: richfaces-tutorial
# Inner Text is:
#
# JFreeChart
#
#
# Title is: None
# href is: jfreechart-tutorial
# Inner Text is:
#
# Java 9
#
#
# Title is: None
# href is: java-9-features
# Inner Text is:
#
# Java 8
#
#
# Title is: None
# href is: java-8-features
# Inner Text is:
#
# JOGL
#
#
# Title is: None
# href is: jogl-tutorial
# Inner Text is:
#
# Tika
#
#
# Title is: None
# href is: tika-tutorial
# Inner Text is:
#
# jBPM
#
#
# Title is: None
# href is: jbpm-tutorial
# Inner Text is:
#
# PDFBox
#
#
# Title is: None
# href is: pdfbox-tutorial
# Inner Text is:
#
# Intellij Idea
#
#
# Title is: None
# href is: https://www.javatpoint.com/intellij-idea-tutorial
# Inner Text is:
#
# SQL
#
#
# Title is: None
# href is: sql-tutorial
# Inner Text is:
#
# PL/SQL
#
#
# Title is: None
# href is: pl-sql-tutorial
# Inner Text is:
#
# MySQL
#
#
# Title is: None
# href is: mysql-tutorial
# Inner Text is:
#
# MongoDB
#
#
# Title is: None
# href is: mongodb-tutorial
# Inner Text is:
#
# PostgreSQL
#
#
# Title is: None
# href is: postgresql-tutorial
# Inner Text is:
#
# SQL Server
#
#
# Title is: None
# href is: sql-server-tutorial
# Inner Text is:
#
# Oracle
#
#
# Title is: None
# href is: oracle-tutorial
# Inner Text is:
#
# Cassandra
#
#
# Title is: None
# href is: cassandra-tutorial
# Inner Text is:
#
# SQLite
#
#
# Title is: None
# href is: sqlite-tutorial
# Inner Text is:
#
# Neo4j
#
#
# Title is: None
# href is: neo4j-tutorial
# Inner Text is:
#
# CouchDB
#
#
# Title is: None
# href is: couchdb-tutorial
# Inner Text is:
#
# MariaDB
#
#
# Title is: None
# href is: mariadb-tutorial
# Inner Text is:
#
# DB2
#
#
# Title is: None
# href is: db2-tutorial
# Inner Text is:
#
# PouchDB
#
#
# Title is: None
# href is: pouchdb-tutorial
# Inner Text is:
#
# Redis
#
#
# Title is: None
# href is: redis-tutorial
# Inner Text is:
#
# HTML
#
#
# Title is: None
# href is: html-tutorial
# Inner Text is:
#
# CSS
#
#
# Title is: None
# href is: css-tutorial
# Inner Text is:
#
# JavaScript
#
#
# Title is: None
# href is: javascript-tutorial
# Inner Text is:
#
# jQuery
#
#
# Title is: None
# href is: jquery-tutorial
# Inner Text is:
#
# jQuery UI
#
#
# Title is: None
# href is: jquery-ui-tutorial
# Inner Text is:
#
# PHP
#
#
# Title is: None
# href is: php-tutorial
# Inner Text is:
#
# XML
#
#
# Title is: None
# href is: xml-tutorial
# Inner Text is:
#
# JSON
#
#
# Title is: None
# href is: json-tutorial
# Inner Text is:
#
# AJAX
#
#
# Title is: None
# href is: ajax-tutorial
# Inner Text is:
#
# Web Serv-
#
#
# Title is: None
# href is: web-services-tutorial
# Inner Text is:
#
# Bootstrap
#
#
# Title is: None
# href is: bootstrap-tutorial
# Inner Text is:
#
# AngularJS
#
#
# Title is: None
# href is: angularjs-tutorial
# Inner Text is:
#
# Node.js
#
#
# Title is: None
# href is: nodejs-tutorial
# Inner Text is:
#
# Express.js
#
#
# Title is: None
# href is: expressjs-tutorial
# Inner Text is:
#
# Backbone
#
#
# Title is: None
# href is: backbonejs-tutorial
# Inner Text is:
#
# Sass
#
#
# Title is: None
# href is: sass-tutorial
# Inner Text is:
#
# Less
#
#
# Title is: None
# href is: less-tutorial
# Inner Text is:
#
# XSLT
#
#
# Title is: None
# href is: xslt-tutorial
# Inner Text is:
#
# XPath
#
#
# Title is: None
# href is: xpath-tutorial
# Inner Text is:
#
# XQuery
#
#
# Title is: None
# href is: xquery-tutorial
# Inner Text is:
#
# XHTML
#
#
# Title is: None
# href is: xhtml-tutorial
# Inner Text is:
#
# Pure.CSS
#
#
# Title is: None
# href is: pure-css-tutorial
# Inner Text is:
#
# Materialize
#
#
# Title is: None
# href is: materialize-css-tutorial
# Inner Text is:
#
# Framework7
#
#
# Title is: None
# href is: framework7-tutorial
# Inner Text is:
#
# HTTP
#
#
# Title is: None
# href is: https://www.javatpoint.com/http-tutorial
# Inner Text is:
#
# DHTML
#
#
# Title is: None
# href is: https://www.javatpoint.com/dhtml
# Inner Text is:
#
# PHP
#
#
# Title is: None
# href is: php-tutorial
# Inner Text is:
#
# Laravel
#
#
# Title is: None
# href is: https://www.javatpoint.com/laravel
# Inner Text is:
#
# WordPress
#
#
# Title is: None
# href is: wordpress-tutorial
# Inner Text is:
#
# CodeIgniter
#
#
# Title is: None
# href is: codeigniter-tutorial
# Inner Text is:
#
# Magento 2
#
#
# Title is: None
# href is: https://www.javatpoint.com/magento-2
# Inner Text is:
#
# Joomla
#
#
# Title is: None
# href is: https://www.javatpoint.com/joomla
# Inner Text is:
#
# Phalcon
#
#
# Title is: None
# href is: phalcon-tutorial
# Inner Text is:
#
# YII
#
#
# Title is: None
# href is: yii-tutorial
# Inner Text is:
#
# Xampp
#
#
# Title is: None
# href is: https://www.javatpoint.com/xampp
# Inner Text is:
#
# Excel
#
#
# Title is: None
# href is: excel-tutorial
# Inner Text is:
#
# MS Word
#
#
# Title is: None
# href is: ms-word-tutorial
# Inner Text is:
#
# Powerpoint
#
#
# Title is: None
# href is: powerpoint-tutorial
# Inner Text is:
#
# OneNote
#
#
# Title is: None
# href is: https://www.javatpoint.com/onenote
# Inner Text is:
#
# VBA
#
#
# Title is: None
# href is: https://www.javatpoint.com/vba
# Inner Text is:
#
# Power BI
#
#
# Title is: None
# href is: https://www.javatpoint.com/power-bi
# Inner Text is:
#
# QlikView
#
#
# Title is: None
# href is: https://www.javatpoint.com/qlikview
# Inner Text is:
#
# Powershell
#
#
# Title is: None
# href is: https://www.javatpoint.com/powershell
# Inner Text is:
#
# Classroom
#
#
# Title is: None
# href is: https://www.javatpoint.com/google-classroom
# Inner Text is:
#
# Smartsheet
#
#
# Title is: None
# href is: https://www.javatpoint.com/smartsheet
# Inner Text is:
#
# .Net
#
#
# Title is: None
# href is: net-framework
# Inner Text is:
#
# C#
#
#
# Title is: None
# href is: c-sharp-tutorial
# Inner Text is:
#
# ASP.NET
#
#
# Title is: None
# href is: asp-net-tutorial
# Inner Text is:
#
# ADO.NET
#
#
# Title is: None
# href is: ado-net-tutorial
# Inner Text is:
#
# WPF
#
#
# Title is: None
# href is: wpf
# Inner Text is:
#
# SSRS
#
#
# Title is: None
# href is: https://www.javatpoint.com/ssrs
# Inner Text is:
#
# SSIS
#
#
# Title is: None
# href is: https://www.javatpoint.com/ssis
# Inner Text is:
#
# Web API
#
#
# Title is: None
# href is: https://www.javatpoint.com/web-api
# Inner Text is:
#
# LINQ
#
#
# Title is: None
# href is: https://www.javatpoint.com/linq
# Inner Text is:
#
# SharePoint
#
#
# Title is: None
# href is: https://www.javatpoint.com/sharepoint
# Inner Text is:
#
# F#
#
#
# Title is: None
# href is: f-sharp-tutorial
# Inner Text is:
#
# VB.NET
#
#
# Title is: None
# href is: vb-net
# Inner Text is:
#
# C
#
#
# Title is: None
# href is: c-programming-language-tutorial
# Inner Text is:
#
# C++
#
#
# Title is: None
# href is: cpp-tutorial
# Inner Text is:
#
# Android
#
#
# Title is: None
# href is: android-tutorial
# Inner Text is:
#
# Computer
#
#
# Title is: None
# href is: computer-fundamentals-tutorial
# Inner Text is:
#
# Linux
#
#
# Title is: None
# href is: linux-tutorial
# Inner Text is:
#
# vi editor
#
#
# Title is: None
# href is: vi-editor
# Inner Text is:
#
# Embedded
#
#
# Title is: None
# href is: embedded-system-tutorial
# Inner Text is:
#
# Robotics
#
#
# Title is: None
# href is: robotics-tutorial
# Inner Text is:
#
# SEO
#
#
# Title is: None
# href is: seo-tutorial
# Inner Text is:
#
# Shell Script
#
#
# Title is: None
# href is: shell-scripting-tutorial
# Inner Text is:
#
# MathML
#
#
# Title is: None
# href is: mathml-tutorial
# Inner Text is:
#
# Perl
#
#
# Title is: None
# href is: perl-tutorial
# Inner Text is:
#
# Scala
#
#
# Title is: None
# href is: scala-tutorial
# Inner Text is:
#
# Ruby
#
#
# Title is: None
# href is: ruby-tutorial
# Inner Text is:
#
# Rails
#
#
# Title is: None
# href is: ruby-on-rails-tutorial
# Inner Text is:
#
# Docker
#
#
# Title is: None
# href is: docker-tutorial
# Inner Text is:
#
# GWT
#
#
# Title is: None
# href is: gwt-tutorial
# Inner Text is:
#
# Go Lang
#
#
# Title is: None
# href is: go-tutorial
# Inner Text is:
#
# On Ubuntu
#
#
# Title is: None
# href is: software-installation-in-ubuntu
# Inner Text is:
#
# On Mac
#
#
# Title is: None
# href is: software-installation-on-mac
# Inner Text is:
#
# On CentOS
#
#
# Title is: None
# href is: software-installation-on-centos
# Inner Text is:
#
# SVG
#
#
# Title is: None
# href is: svg-tutorial
# Inner Text is:
#
# Polymer
#
#
# Title is: None
# href is: polymer-tutorial
# Inner Text is:
#
# Kotlin
#
#
# Title is: None
# href is: kotlin-tutorial
# Inner Text is:
#
# Rust
#
#
# Title is: None
# href is: https://www.javatpoint.com/rust-tutorial
# Inner Text is:
#
# Control System
#
#
# Title is: None
# href is: https://www.javatpoint.com/control-system-tutorial
# Inner Text is:
#
# TypeScript
#
#
# Title is: None
# href is: https://www.javatpoint.com/typescript-tutorial
# Inner Text is:
#
# Pig
#
#
# Title is: None
# href is: https://www.javatpoint.com/pig
# Inner Text is:
#
# Swift
#
#
# Title is: None
# href is: https://www.javatpoint.com/swift-tutorial
# Inner Text is:
#
# Spark
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-spark-tutorial
# Inner Text is:
#
# DIP
#
#
# Title is: None
# href is: https://www.javatpoint.com/digital-image-processing-tutorial
# Inner Text is:
#
# Mobile Communication
#
#
# Title is: None
# href is: https://www.javatpoint.com/mobile-communication-tutorial
# Inner Text is:
#
# SAS
#
#
# Title is: None
# href is: https://www.javatpoint.com/sas-tutorial
# Inner Text is:
#
# Electrical Machines
#
#
# Title is: None
# href is: https://www.javatpoint.com/electrical-machines-tutorial
# Inner Text is:
#
# Hive
#
#
# Title is: None
# href is: https://www.javatpoint.com/hive
# Inner Text is:
#
# Tableau
#
#
# Title is: None
# href is: https://www.javatpoint.com/tableau
# Inner Text is:
#
# NGINX
#
#
# Title is: None
# href is: https://www.javatpoint.com/nginx-tutorial
# Inner Text is:
#
# Log4j
#
#
# Title is: None
# href is: https://www.javatpoint.com/log4j
# Inner Text is:
#
# Bash
#
#
# Title is: None
# href is: https://www.javatpoint.com/bash
# Inner Text is:
#
# R
#
#
# Title is: None
# href is: https://www.javatpoint.com/r-tutorial
# Inner Text is:
#
# Git
#
#
# Title is: None
# href is: https://www.javatpoint.com/git
# Inner Text is:
#
# Wireshark
#
#
# Title is: None
# href is: https://www.javatpoint.com/wireshark
# Inner Text is:
#
# Xamarin
#
#
# Title is: None
# href is: https://www.javatpoint.com/xamarin
# Inner Text is:
#
# Tensorflow
#
#
# Title is: None
# href is: https://www.javatpoint.com/tensorflow
# Inner Text is:
#
# VHDL
#
#
# Title is: None
# href is: https://www.javatpoint.com/vhdl
# Inner Text is:
#
# Ionic
#
#
# Title is: None
# href is: https://www.javatpoint.com/ionic
# Inner Text is:
#
# NLP
#
#
# Title is: None
# href is: https://www.javatpoint.com/nlp
# Inner Text is:
#
# Latex
#
#
# Title is: None
# href is: https://www.javatpoint.com/latex
# Inner Text is:
#
# Inkscape
#
#
# Title is: None
# href is: https://www.javatpoint.com/inkscape
# Inner Text is:
#
# Matlab
#
#
# Title is: None
# href is: https://www.javatpoint.com/matlab
# Inner Text is:
#
# GitHub
#
#
# Title is: None
# href is: https://www.javatpoint.com/github
# Inner Text is:
#
# Unity
#
#
# Title is: None
# href is: https://www.javatpoint.com/unity
# Inner Text is:
#
# SVN
#
#
# Title is: None
# href is: https://www.javatpoint.com/svn
# Inner Text is:
#
# Reinforcement
#
#
# Title is: None
# href is: https://www.javatpoint.com/reinforcement-learning
# Inner Text is:
#
# Kafka
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-kafka
# Inner Text is:
#
# Kali Linux
#
#
# Title is: None
# href is: https://www.javatpoint.com/kali-linux
# Inner Text is:
#
# Talend
#
#
# Title is: None
# href is: https://www.javatpoint.com/talend
# Inner Text is:
#
# Mockito
#
#
# Title is: None
# href is: https://www.javatpoint.com/mockito
# Inner Text is:
#
# Ansible
#
#
# Title is: None
# href is: https://www.javatpoint.com/ansible
# Inner Text is:
#
# Firebase
#
#
# Title is: None
# href is: https://www.javatpoint.com/firebase
# Inner Text is:
#
# Cobol
#
#
# Title is: None
# href is: https://www.javatpoint.com/cobol
# Inner Text is:
#
# ES6
#
#
# Title is: None
# href is: https://www.javatpoint.com/es6
# Inner Text is:
#
# Flutter
#
#
# Title is: None
# href is: https://www.javatpoint.com/flutter
# Inner Text is:
#
# Gradle
#
#
# Title is: None
# href is: https://www.javatpoint.com/gradle
# Inner Text is:
#
# UML
#
#
# Title is: None
# href is: https://www.javatpoint.com/uml
# Inner Text is:
#
# ANN
#
#
# Title is: None
# href is: https://www.javatpoint.com/artificial-neural-network
# Inner Text is:
#
# Tally
#
#
# Title is: None
# href is: https://www.javatpoint.com/tally
# Inner Text is:
#
# Godot
#
#
# Title is: None
# href is: https://www.javatpoint.com/godot
# Inner Text is:
#
# AutoCad
#
#
# Title is: None
# href is: https://www.javatpoint.com/autocad
# Inner Text is:
#
# Kubernetes
#
#
# Title is: None
# href is: https://www.javatpoint.com/kubernetes
# Inner Text is:
#
# Puppet
#
#
# Title is: None
# href is: https://www.javatpoint.com/puppet
# Inner Text is:
#
# Math
#
#
# Title is: None
# href is: https://www.javatpoint.com/math
# Inner Text is:
#
# GDB
#
#
# Title is: None
# href is: https://www.javatpoint.com/gdb
# Inner Text is:
#
# Fuzzy Logic
#
#
# Title is: None
# href is: https://www.javatpoint.com/fuzzy-logic
# Inner Text is:
#
# Proc*C
#
#
# Title is: None
# href is: https://www.javatpoint.com/proc
# Inner Text is:
#
# SMM
#
#
# Title is: None
# href is: https://www.javatpoint.com/social-media-marketing
# Inner Text is:
#
# Affiliate Marketing
#
#
# Title is: None
# href is: https://www.javatpoint.com/affiliate-marketing
# Inner Text is:
#
# Arduino
#
#
# Title is: None
# href is: https://www.javatpoint.com/arduino
# Inner Text is:
#
# Digital Electronics
#
#
# Title is: None
# href is: https://www.javatpoint.com/digital-electronics
# Inner Text is:
#
# Adwords
#
#
# Title is: None
# href is: https://www.javatpoint.com/google-adwords
# Inner Text is:
#
# Ext.js
#
#
# Title is: None
# href is: https://www.javatpoint.com/ext-js
# Inner Text is:
#
# GraphQL
#
#
# Title is: None
# href is: https://www.javatpoint.com/graphql
# Inner Text is:
#
# IoT
#
#
# Title is: None
# href is: https://www.javatpoint.com/iot-internet-of-things
# Inner Text is:
#
# Gmail
#
#
# Title is: None
# href is: https://www.javatpoint.com/gmail
# Inner Text is:
#
# Vue.js
#
#
# Title is: None
# href is: https://www.javatpoint.com/vue-js
# Inner Text is:
#
# Landing Page
#
#
# Title is: None
# href is: https://www.javatpoint.com/landing-pages
# Inner Text is:
#
# PLC
#
#
# Title is: None
# href is: https://www.javatpoint.com/plc
# Inner Text is:
#
# Illustrator
#
#
# Title is: None
# href is: https://www.javatpoint.com/adobe-illustrator
# Inner Text is:
#
# Memcached
#
#
# Title is: None
# href is: https://www.javatpoint.com/memcached-tutorial
# Inner Text is:
#
# Solr
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-solr
# Inner Text is:
#
# Gimp
#
#
# Title is: None
# href is: https://www.javatpoint.com/gimp
# Inner Text is:
#
# Verilog
#
#
# Title is: None
# href is: https://www.javatpoint.com/verilog
# Inner Text is:
#
# Teradata
#
#
# Title is: None
# href is: https://www.javatpoint.com/teradata
# Inner Text is:
#
# PhoneGap
#
#
# Title is: None
# href is: https://www.javatpoint.com/phonegap
# Inner Text is:
#
# Bootstrap 4
#
#
# Title is: None
# href is: https://www.javatpoint.com/bootstrap-4
# Inner Text is:
#
# Chrome
#
#
# Title is: None
# href is: https://www.javatpoint.com/what-is-google-chrome
# Inner Text is:
#
# Dart
#
#
# Title is: None
# href is: https://www.javatpoint.com/dart-programming
# Inner Text is:
#
# Adobe After Effects
#
#
# Title is: None
# href is: https://www.javatpoint.com/adobe-after-effect
# Inner Text is:
#
# Adobe Dreamweaver
#
#
# Title is: None
# href is: https://www.javatpoint.com/adobe-dreamweaver
# Inner Text is:
#
# Adobe CorelDRAW
#
#
# Title is: None
# href is: https://www.javatpoint.com/coreldraw
# Inner Text is:
#
# Adobe Indesign
#
#
# Title is: None
# href is: https://www.javatpoint.com/adobe-indesign
# Inner Text is:
#
# Audacity
#
#
# Title is: None
# href is: https://www.javatpoint.com/audacity
# Inner Text is:
#
# Blue Prism
#
#
# Title is: None
# href is: https://www.javatpoint.com/blue-prism
# Inner Text is:
#
# Python CGI Programming
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-cgi-programming
# Inner Text is:
#
# Cordova
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-cordova
# Inner Text is:
#
# d3.js
#
#
# Title is: None
# href is: https://www.javatpoint.com/d3-js
# Inner Text is:
#
# Dialogflow
#
#
# Title is: None
# href is: https://www.javatpoint.com/dialogflow
# Inner Text is:
#
# Ionic
#
#
# Title is: None
# href is: https://www.javatpoint.com/ionic
# Inner Text is:
#
# ITIL
#
#
# Title is: None
# href is: https://www.javatpoint.com/itil
# Inner Text is:
#
# IOS with Swift
#
#
# Title is: None
# href is: https://www.javatpoint.com/ios-development-using-swift
# Inner Text is:
#
# Angular Material
#
#
# Title is: None
# href is: https://www.javatpoint.com/angular-material
# Inner Text is:
#
# Deep Learning
#
#
# Title is: None
# href is: https://www.javatpoint.com/deep-learning
# Inner Text is:
#
# Google Colab
#
#
# Title is: None
# href is: https://www.javatpoint.com/python-programming-with-google-colab
# Inner Text is:
#
# Graph Theory
#
#
# Title is: None
# href is: https://www.javatpoint.com/graph-theory
# Inner Text is:
#
# Groovy
#
#
# Title is: None
# href is: https://www.javatpoint.com/groovy
# Inner Text is:
#
# Group Discussion
#
#
# Title is: None
# href is: https://www.javatpoint.com/group-discussion
# Inner Text is:
#
# Informatica
#
#
# Title is: None
# href is: https://www.javatpoint.com/informatica
# Inner Text is:
#
# Digital Marketing
#
#
# Title is: None
# href is: https://www.javatpoint.com/digital-marketing
# Inner Text is:
#
# Elasticsearch
#
#
# Title is: None
# href is: https://www.javatpoint.com/elasticsearch
# Inner Text is:
#
# Entity Framework
#
#
# Title is: None
# href is: https://www.javatpoint.com/entity-framework
# Inner Text is:
#
# Firewall
#
#
# Title is: None
# href is: https://www.javatpoint.com/firewall
# Inner Text is:
#
# Functional Programming
#
#
# Title is: None
# href is: https://www.javatpoint.com/functional-programming
# Inner Text is:
#
# Photoshop
#
#
# Title is: None
# href is: https://www.javatpoint.com/photoshop
# Inner Text is:
#
# Prolog
#
#
# Title is: None
# href is: https://www.javatpoint.com/prolog
# Inner Text is:
#
# PWA
#
#
# Title is: None
# href is: https://www.javatpoint.com/progressive-web-applications
# Inner Text is:
#
# Pyspark
#
#
# Title is: None
# href is: https://www.javatpoint.com/pyspark
# Inner Text is:
#
# Nagios
#
#
# Title is: None
# href is: https://www.javatpoint.com/nagios
# Inner Text is:
#
# Nifi
#
#
# Title is: None
# href is: https://www.javatpoint.com/apache-nifi
# Inner Text is:
#
# Online Marketing
#
#
# Title is: None
# href is: https://www.javatpoint.com/online-marketing
# Inner Text is:
#
# OpenStack
#
#
# Title is: None
# href is: https://www.javatpoint.com/openstack
# Inner Text is:
#
# PDF
#
#
# Title is: None
# href is: https://www.javatpoint.com/pdf
# Inner Text is:
#
# Kibana
#
#
# Title is: None
# href is: https://www.javatpoint.com/kibana
# Inner Text is:
#
# Mean Stack
#
#
# Title is: None
# href is: https://www.javatpoint.com/mean-stack-tutorial
# Inner Text is:
#
# Microprocessor
#
#
# Title is: None
# href is: https://www.javatpoint.com/microprocessor-tutorial
# Inner Text is:
#
# Mobile Computing
#
#
# Title is: None
# href is: https://www.javatpoint.com/mobile-computing
# Inner Text is:
#
# Mobile Testing
#
#
# Title is: None
# href is: https://www.javatpoint.com/mobile-application-testing
# Inner Text is:
#
# Interview Questions
#
#
# Title is: None
# href is: interview-questions-and-answers
# Inner Text is:
#
# Projects
#
#
# Title is: None
# href is: free-java-projects
# Inner Text is:
#
# Java Compiler
#
#
# Title is: None
# href is: https://compiler.javatpoint.com/opr/online-java-compiler.jsp
# Inner Text is:
#
# Full Form
#
#
# Title is: None
# href is: full-form
# Inner Text is:
#
# Difference
#
#
# Title is: None
# href is: difference-between
# Inner Text is:
#
# Health
#
#
# Title is: None
# href is: how-to-lose-weight
# Inner Text is:
#
# HR
#
#
# Title is: None
# href is: hr-tutorial
# Inner Text is:
#
# Marketing
#
#
# Title is: None
# href is: marketing-tutorial
# Inner Text is:
#
# Quotes
#
#
# Title is: None
# href is: https://www.quoteperson.com
# Inner Text is: - About Me
# Title is: None
# href is: sonoo-jaiswal
# Inner Text is: 14-days Semrush Free Pro Trial
# Title is: None
# href is: https://semrush.sjv.io/c/4124850/1648349/13053
# Inner Text is: [email protected]
# Title is: None
# href is: /cdn-cgi/l/email-protection
# Inner Text is: 4th Jul - Wireless Backhaul
# Title is: None
# href is: wireless-backhaul
# Inner Text is: 4th Jul - Define Protocol in Computer Network
# Title is: None
# href is: define-protocol-in-computer-network
# Inner Text is: 4th Jul - Virtual Network Adapter
# Title is: None
# href is: virtual-network-adapter
# Inner Text is: 4th Jul - Virtual Routing and Forwarding
# Title is: None
# href is: virtual-routing-and-forwarding
# Inner Text is: 4th Jul - Virtual Switches(vSwitches)
# Title is: None
# href is: virtual-switches
# Inner Text is: 4th Jul - VLAN (Virtual LAN)
# Title is: None
# href is: vlan-virtual-lan
# Inner Text is: 4th Jul - Wireless Mesh Network (WMN)
# Title is: None
# href is: wireless-mesh-network-wmn
# Inner Text is: 4th Jul - What is Gateway in Computer Network
# Title is: None
# href is: what-is-gateway-in-computer-network
# Inner Text is: 4th Jul - Radio Access Network (RAN)
# Title is: None
# href is: radio-access-network-ran
# Inner Text is: 4th Jul - What is File Sharing
# Title is: None
# href is: what-is-file-sharing
# Inner Text is: 4th Jul - Passive Optical Network (PON)
# Title is: None
# href is: passive-optical-network-pon
# Inner Text is: 4th Jul - Private IP address
# Title is: None
# href is: private-ip-address
# Inner Text is: 4th Jul - Public Key Certificate
# Title is: None
# href is: public-key-certificate
# Inner Text is: 4th Jul - What is Bridge in Computer Network
# Title is: None
# href is: what-is-bridge-in-computer-network
# Inner Text is: 4th Jul - Ping Sweep (ICMP Sweep)
# Title is: None
# href is: ping-sweep-icmp-sweep
# Inner Text is: 4th Jul - Print Server
# Title is: None
# href is: print-server
# Inner Text is: 4th Jul - WIFI Pineapple
# Title is: None
# href is: wifi-pineapple
# Inner Text is: 4th Jul - Walled Garden
# Title is: None
# href is: walled-garden
# Inner Text is: 4th Jul - Wireless ISP (wireless Internet service provider or WISP)
# Title is: None
# href is: wireless-isp
# Inner Text is: 4th Jul - Bridge vs Repeater
# Title is: None
# href is: bridge-vs-repeater
# Inner Text is: 4th Jul - Hardware Security Module (HSM)
# Title is: None
# href is: hardware-security-module-hsm
# Inner Text is: 4th Jul - Public Switched Telephone Network
# Title is: None
# href is: public-switched-telephone-network
# Inner Text is: 4th Jul - Analog Telephone Adapter (ATA)
# Title is: None
# href is: analog-telephone-adapter-ata
# Inner Text is: 4th Jul - Host Bus Adapter (HBA)
# Title is: None
# href is: host-bus-adapter-hba
# Inner Text is: 4th Jul - ISCSI initiator
# Title is: None
# href is: iscsi-initiator
# Inner Text is: 4th Jul - Simplest Protocol
# Title is: None
# href is: simplest-protocol
# Inner Text is: 4th Jul - Telecommunication Networks
# Title is: None
# href is: telecommunication-networks
# Inner Text is: 4th Jul - What is WPS in Wi-Fi
# Title is: None
# href is: what-is-wps-in-wi-fi
# Inner Text is: 4th Jul - What are the Most Important Email Security Protocols
# Title is: None
# href is: what-are-the-most-important-email-security-protocols
# Inner Text is: 4th Jul - What is Data Governance and Why does it Matter
# Title is: None
# href is: what-is-data-governance-and-why-does-it-matter
# Inner Text is: 4th Jul - Carrier Network
# Title is: None
# href is: carrier-network
# Inner Text is: 4th Jul - Most Secure Network Protocol
# Title is: None
# href is: most-secure-network-protocol
# Inner Text is: 4th Jul - Network SMB
# Title is: None
# href is: network-smb
# Inner Text is: 4th Jul - BGP vs. EIGRP: What's the Difference
# Title is: None
# href is: bgp-vs-eigrp-whats-the-difference
# Inner Text is: 4th Jul - Wireless Security: WEP, WPA, WPA2 and WPA3 differences
# Title is: None
# href is: wireless-security-wep-wpa-wpa2-and-wpa3-differences
# Inner Text is: 4th Jul - Cloud Radio Access Network (C-RAN)
# Title is: None
# href is: cloud-radio-access-network
# Inner Text is: 4th Jul - Bits Per Second (bps or bit/sec)
# Title is: None
# href is: bits-per-second-bps-or-bit-sec
# Inner Text is: 4th Jul - Blade Server
# Title is: None
# href is: blade-server
# Inner Text is: 4th Jul - command-and-control server (C&C server)
# Title is: None
# href is: command-and-control-server
# Inner Text is: 2nd Jul - Three-Tier Application Architecture
# Title is: None
# href is: three-tier-application-architecture
# Inner Text is: 2nd Jul - What is 3-2-1 Backup Strategy
# Title is: None
# href is: what-is-3-2-1-backup-strategy
# Inner Text is: 2nd Jul - Differential Backup
# Title is: None
# href is: differential-backup
# Inner Text is: 2nd Jul - Information Retrieval in DBMS
# Title is: None
# href is: information-retrieval-in-dbms
# Inner Text is: 2nd Jul - Database Automation
# Title is: None
# href is: database-automation
# Inner Text is: 2nd Jul - Advantages of Relational Databases
# Title is: None
# href is: advantages-of-relational-databases
# Inner Text is: 2nd Jul - Ambiguous Column Name in DBMS
# Title is: None
# href is: ambiguous-column-name-in-dbms
# Inner Text is: 2nd Jul - Ambiguous Column Name in Snowflake
# Title is: None
# href is: ambiguous-column-name-in-snowflake
# Inner Text is: 2nd Jul - Differences between the Relational model and the Document Model
# Title is: None
# href is: differences-between-the-relational-model-and-the-document-model
# Inner Text is: 2nd Jul - Difference between row-oriented and column-oriented data stores dbms
# Title is: None
# href is: difference-between-row-oriented-and-column-oriented-data-stores-dbms
# Inner Text is: 2nd Jul - Null and not null in SQL
# Title is: None
# href is: null-and-not-null-in-sql
# Inner Text is: 2nd Jul - Unique and Distinct Differences in SQL
# Title is: None
# href is: unique-and-distinct-differences-in-sql
# Inner Text is: 2nd Jul - Difference between Exist and Not-Exist Operator
# Title is: None
# href is: difference-between-exist-and-not-exist-operator
# Inner Text is: 2nd Jul - Inner join vs outer join
# Title is: None
# href is: inner-join-vs-outer-join
# Inner Text is: 2nd Jul - Difference between In and Between Operator
# Title is: None
# href is: difference-between-in-and-between-operator
# Inner Text is: 2nd Jul - Minimum relations satisfying 1NF
# Title is: None
# href is: minimum-relations-satisfying-1nf
# Inner Text is: 2nd Jul - Why Recovery is Needed in DBMS
# Title is: None
# href is: why-recovery-is-needed-in-dbms
# Inner Text is: 2nd Jul - Difficulties of Implementing Data Warehouses
# Title is: None
# href is: difficulties-of-implementing-data-warehouses
# Inner Text is: 2nd Jul - How to find the Highest Normal Form of a Relation
# Title is: None
# href is: how-to-find-the-highest-normal-form-of-a-relation
# Inner Text is: 2nd Jul - Difference between Inverted Index and Forward Index
# Title is: None
# href is: difference-between-inverted-index-and-forward-index
# Inner Text is: 2nd Jul - Capturing Insert Timestamps in Table to SQL Server
# Title is: None
# href is: capturing-insert-timestamps-in-table-to-sql-server
# Inner Text is: 2nd Jul - Cassandra vs DynamoDB
# Title is: None
# href is: cassandra-vs-dynamodb
# Inner Text is: 2nd Jul - Characteristics of Biological Data (Genome Data Management)
# Title is: None
# href is: characteristics-of-biological-data-genome-data-management
# Inner Text is: 2nd Jul - convert varchar to int in oracle
# Title is: None
# href is: convert-varchar-to-int-in-oracle
# Inner Text is: 2nd Jul - convert varchar to number in oracle
# Title is: None
# href is: convert-varchar-to-number-in-oracle
# Inner Text is: 2nd Jul - Difference between Hadoop and RDBMS
# Title is: None
# href is: difference-between-hadoop-and-rdbms
# Inner Text is: 2nd Jul - ER diagram of Bank Management System
# Title is: None
# href is: er-diagram-of-bank-management-system
# Inner Text is: 2nd Jul - How to Reset Identity Column Values in SQL
# Title is: None
# href is: how-to-reset-identity-column-values-in-sql
# Inner Text is: 2nd Jul - Join Operation Vs Nested Query
# Title is: None
# href is: join-operation-vs-nested-query
# Inner Text is: 2nd Jul - SQL Query to Display Last 5 Records employee Table
# Title is: None
# href is: sql-query-to-display-last-5-records-employee-table
# Inner Text is: 2nd Jul - Thomas Write Rule in Database Management Systems (DBMS)
# Title is: None
# href is: thomas-write-rule-in-database-management-systems-dbms
# Inner Text is: 2nd Jul - Web Information Retrieval | Vector Space Model
# Title is: None
# href is: web-information-retrieval-vector-space-model
# Inner Text is: 2nd Jul - CHAR vs VARCHAR in SQL
# Title is: None
# href is: char-vs-varchar-in-sql
# Inner Text is: 2nd Jul - Difference between Database and DBMS
# Title is: None
# href is: difference-between-database-and-dbms
# Inner Text is: 2nd Jul - Difference between Natural Join and Inner Join in SQL
# Title is: None
# href is: difference-between-natural-join-and-inner-join-in-sql
# Inner Text is: 2nd Jul - How DBMS Stores Data
# Title is: None
# href is: how-dbms-stores-data
# Inner Text is: 2nd Jul - How do Keys Contribute to Referential Integrity
# Title is: None
# href is: how-do-keys-contribute-to-referential-integrity
# Inner Text is: 2nd Jul - What is Query Rewriting Techniques in DBMS
# Title is: None
# href is: what-is-query-rewriting-techniques-in-dbms
# Inner Text is: 2nd Jul - What is Record-at-a-Time in DBMS
# Title is: None
# href is: what-is-record-at-a-time-in-dbms
# Inner Text is: 2nd Jul - What is Scalability in DBMS and How to achieve it
# Title is: None
# href is: what-is-scalability-in-dbms-and-how-to-achieve-it
# Inner Text is: 2nd Jul - What is user authentication in DBMS
# Title is: None
# href is: what-is-user-authentication-in-dbms
# Inner Text is: 2nd Jul - Blind Write in DBMS
# Title is: None
# href is: blind-write-in-dbms
# Inner Text is: 2nd Jul - Differences between Super Key and Candidate Key
# Title is: None
# href is: differences-between-super-key-and-candidate-key
# Inner Text is: 2nd Jul - How do Keys Assist in Indexing Strategies
# Title is: None
# href is: how-do-keys-assist-in-indexing-strategies
# Inner Text is: 2nd Jul - How to draw an ER diagram in DBMS
# Title is: None
# href is: how-to-draw-an-er-diagram-in-dbms
# Inner Text is: 2nd Jul - What is Transparent DBMS
# Title is: None
# href is: what-is-transparent-dbms
# Inner Text is: 2nd Jul - What is RDBMS Kernel
# Title is: None
# href is: what-is-rdbms-kernel
# Inner Text is: 2nd Jul - What is Temporal Query Language (TQL)
# Title is: None
# href is: what-is-temporal-query-language-tql
# Inner Text is: 2nd Jul - What are Stand-Alone Procedures
# Title is: None
# href is: what-are-stand-alone-procedures
# Inner Text is: 2nd Jul - What is Lock Escalation
# Title is: None
# href is: what-is-lock-escalation
# Inner Text is: 2nd Jul - How DBMS Performance is Improved
# Title is: None
# href is: how-dbms-performance-is-improved
# Inner Text is: 2nd Jul - Multivalued Dependency and Fourth Normal Form
# Title is: None
# href is: multivalued-dependency-and-fourth-normal-form
# Inner Text is: 2nd Jul - What is the relationship between ODBC, OLE DB, and ADO
# Title is: None
# href is: what-is-the-relationship-between-odbc-ole-db-and-ado
# Inner Text is: 2nd Jul - Difference between UNIQUE and UNIQUE All
# Title is: None
# href is: difference-between-unique-and-unique-all
# Inner Text is: 2nd Jul - What is a Record in DBMS
# Title is: None
# href is: what-is-a-record-in-dbms
# Inner Text is: 2nd Jul - Difference between Super key and Candidate key
# Title is: None
# href is: difference-between-super-key-and-candidate-key
# Inner Text is: 1st Jul - 10 Famous React Apps
# Title is: None
# href is: 10-famous-react-apps
# Inner Text is: 1st Jul - React Dropdown
# Title is: None
# href is: react-dropdown
# Inner Text is: 1st Jul - Composition vs. Inheritance React
# Title is: None
# href is: composition-vs-inheritance-react
# Inner Text is: 1st Jul - comment html in react
# Title is: None
# href is: comment-html-in-react
# Inner Text is: 1st Jul - Component vs. Purecomponent React
# Title is: None
# href is: component-vs-purecomponent-react
# Inner Text is: 1st Jul - Compare Angular React and Vue
# Title is: None
# href is: compare-angular-react-and-vue
# Inner Text is: 1st Jul - Complete React JS from Zero to Hero Get Hired
# Title is: None
# href is: complete-react-js-from-zero-to-hero-get-hired
# Inner Text is: 1st Jul - Const in ReactJS
# Title is: None
# href is: const-in-reactjs
# Inner Text is: 1st Jul - Convert ejs to React
# Title is: None
# href is: convert-ejs-to-react
# Inner Text is: 1st Jul - React DevTools
# Title is: None
# href is: react-devtools
# Inner Text is: 1st Jul - ReactJS Jobs
# Title is: None
# href is: reactjs-jobs
# Inner Text is: 1st Jul - Conditional Classes in React
# Title is: None
# href is: conditional-classes-in-react
# Inner Text is: 1st Jul - Component React
# Title is: None
# href is: component-react
# Inner Text is: 1st Jul - Constructor in Functional
# Title is: None
# href is: constructor-in-functional
# Inner Text is: 1st Jul - Convert String to Component React
# Title is: None
# href is: convert-string-to-component-react
# Inner Text is: 1st Jul - React in Css
# Title is: None
# href is: react-in-css
# Inner Text is: 1st Jul - React Devtools Extension
# Title is: None
# href is: react-devtools-extension
# Inner Text is: 26th Jun - How to Roll Down the Windows With Your Key Fob
# Title is: None
# href is: how-to-roll-down-the-windows-with-your-key-fob
# Inner Text is: 26th Jun - How to Be a Professional Teacher
# Title is: None
# href is: how-to-be-a-professional-teacher
# Inner Text is: 26th Jun - How to Write a Notable Editorial
# Title is: None
# href is: how-to-write-a-notable-editorial
# Inner Text is: 26th Jun - How to Turn Your Hobby into Your Career
# Title is: None
# href is: how-to-turn-your-hobby-into-your-career
# Inner Text is: 26th Jun - How to Mediate Family Arguments
# Title is: None
# href is: how-to-mediate-family-arguments
# Inner Text is: 26th Jun - How to Lace Shoes
# Title is: None
# href is: how-to-lace-shoes
# Inner Text is: 26th Jun - How to Download a Picture from Instagram
# Title is: None
# href is: how-to-download-a-picture-from-instagram
# Inner Text is: 26th Jun - How to Play Badminton
# Title is: None
# href is: how-to-play-badminton
# Inner Text is: 26th Jun - How To Be Self-Employed
# Title is: None
# href is: how-to-be-self-employed
# Inner Text is: 26th Jun - How To Check If Your Gmail Account Has Been Hacked
# Title is: None
# href is: how-to-check-if-your-gmail-account-has-been-hacked
# Inner Text is: 26th Jun - How to Choose a Cutting Board
# Title is: None
# href is: how-to-choose-a-cutting-board
# Inner Text is: 26th Jun - How to Cover Logos on Clothes
# Title is: None
# href is: how-to-cover-logos-on-clothes
# Inner Text is: 26th Jun - How to Create a Group in WhatsApp
# Title is: None
# href is: how-to-create-a-group-in-whatsapp
# Inner Text is: 26th Jun - How to Create an Educational Scholarship Fund
# Title is: None
# href is: how-to-create-an-educational-scholarship-fund
# Inner Text is: 26th Jun - How to Study in One Day
# Title is: None
# href is: how-to-study-in-one-day
# Inner Text is: 26th Jun - How to Prepare for UPSC Without Coaching
# Title is: None
# href is: how-to-prepare-for-upsc-without-coaching
# Inner Text is: 26th Jun - How to Increase NAD Levels
# Title is: None
# href is: how-to-increase-nad-levels
# Inner Text is: 26th Jun - How To Travel Abroad Alone As A Teenager
# Title is: None
# href is: how-to-travel-abroad-alone-as-a-teenager
# Inner Text is: 26th Jun - How to Write a Briefing Paper
# Title is: None
# href is: how-to-write-a-briefing-paper
# Inner Text is: 26th Jun - How to Make Shawarma
# Title is: None
# href is: how-to-make-shawarma
# Inner Text is: 26th Jun - How to Get a Job With No Experience
# Title is: None
# href is: how-to-get-a-job-with-no-experience
# Inner Text is: 26th Jun - How To Write a Conclusion
# Title is: None
# href is: how-to-write-a-conclusion
# Inner Text is: 26th Jun - How to Travel Alone
# Title is: None
# href is: how-to-travel-alone
# Inner Text is: 26th Jun - How to Boost Your Self-Confidence Quickly
# Title is: None
# href is: how-to-boost-your-self-confidence-quickly
# Inner Text is: 26th Jun - How to Choose a Good Book
# Title is: None
# href is: how-to-choose-a-good-book
# Inner Text is: 26th Jun - How to Write a Review
# Title is: None
# href is: how-to-write-a-review
# Inner Text is: 26th Jun - How many Grams in a Cup
# Title is: None
# href is: how-many-grams-in-a-cup
# Inner Text is: 26th Jun - How to Buy Wine for a Gift
# Title is: None
# href is: how-to-buy-wine-for-a-gift
# Inner Text is: 26th Jun - How to Do Well in School
# Title is: None
# href is: how-to-do-well-in-school
# Inner Text is: 26th Jun - How to Eat Maple Seeds
# Title is: None
# href is: how-to-eat-maple-seeds
# Inner Text is: 26th Jun - How to Keep Cilantro Fresh
# Title is: None
# href is: how-to-keep-cilantro-fresh
# Inner Text is: 26th Jun - How to Overcome Selective Mutism
# Title is: None
# href is: how-to-overcome-selective-mutism
# Inner Text is: 26th Jun - How to Roast Peanuts
# Title is: None
# href is: how-to-roast-peanuts
# Inner Text is: 26th Jun - How to Season Cutting Boards
# Title is: None
# href is: how-to-season-cutting-boards
# Inner Text is: 26th Jun - How to Sell Books
# Title is: None
# href is: how-to-sell-books
# Inner Text is: 26th Jun - How To Clean Your Room
# Title is: None
# href is: how-to-clean-your-room
# Inner Text is: 26th Jun - How to Defrost Food Quickly
# Title is: None
# href is: how-to-defrost-food-quickly
# Inner Text is: 26th Jun - How to Plan a Picnic
# Title is: None
# href is: how-to-plan-a-picnic
# ...
# Inner Text is: 22nd Jun - Difference Between Merger and Acquisition
# Title is: None
# href is: difference-between-merger-and-acquisition
# Inner Text is: 22nd Jun - Difference Between Mission Statement and Vision Statement
# Title is: None
# href is: difference-between-mission-statement-and-vision-statement
# Inner Text is: 22nd Jun - Difference Between MLA and APA
# Title is: None
# href is: difference-between-mla-and-apa
# Inner Text is: 22nd Jun - Difference Between Moody's and S and P Ratings
# Title is: None
# href is: difference-between-moodys-and-s-and-p-ratings
# Inner Text is: 22nd Jun - Difference Between MLA And MP
# Title is: None
# href is: difference-between-mla-and-mp
# Inner Text is: 22nd Jun - Difference Between Net Sales and Net Income
# Title is: None
# href is: difference-between-net-sales-and-net-income
# Inner Text is: 22nd Jun - Difference Between Packing and Packaging
# Title is: None
# href is: difference-between-packing-and-packaging
# Inner Text is: 22nd Jun - Difference Between Pancreatic Cyst and Pseudocyst
# Title is: None
# href is: difference-between-pancreatic-cyst-and-pseudocyst
# Inner Text is: 22nd Jun - Difference Between Paraplegia and Paraparesis
# Title is: None
# href is: difference-between-paraplegia-and-paraparesis
# Inner Text is: 22nd Jun - Difference Between Passive and Non-passive Income
# Title is: None
# href is: difference-between-passive-and-non-passive-income
# Inner Text is: 22nd Jun - Difference Between Pinot Grigio And Sauvignon Blanc
# Title is: None
# href is: difference-between-pinot-grigio-and-sauvignon-blanc
# Inner Text is: 22nd Jun - Difference between Political Science and Politics
# Title is: None
# href is: difference-between-political-science-and-politics
# Inner Text is: 22nd Jun - Difference Between Population Growth and Population Change
# Title is: None
# href is: difference-between-population-growth-and-population-change
# Inner Text is: 22nd Jun - Difference Between Insolvency And Bankruptcy
# Title is: None
# href is: difference-between-insolvency-and-bankruptcy
# Inner Text is: 22nd Jun - Difference Between Journalism and Mass Communication
# Title is: None
# href is: difference-between-journalism-and-mass-communication
# Inner Text is: 22nd Jun - Difference Between Life Insurance and Health Insurance
# Title is: None
# href is: difference-between-life-insurance-and-health-insurance
# Inner Text is: 22nd Jun - Difference Between Positive and Negative Reinforcement
# Title is: None
# href is: difference-between-positive-and-negative-reinforcement
# Inner Text is: 22nd Jun - Difference Between Quite and Quiet
# Title is: None
# href is: difference-between-quite-and-quiet
# Inner Text is: 22nd Jun - Difference Between Sales and Business Development
# Title is: None
# href is: difference-between-sales-and-business-development
# Inner Text is: 22nd Jun - Difference Between Stocks and Bonds
# Title is: None
# href is: difference-between-stocks-and-bonds
# Inner Text is: 22nd Jun - Difference Between Summary and Paraphrase
# Title is: None
# href is: difference-between-summary-and-paraphrase
# Inner Text is: 22nd Jun - Difference Between Supermarket and Hypermarket
# Title is: None
# href is: difference-between-supermarket-and-hypermarket
# Inner Text is: 22nd Jun - Difference Between Syntax and Grammar
# Title is: None
# href is: difference-between-syntax-and-grammar
# Inner Text is: 22nd Jun - Difference Between Avoidable and Unavoidable Cost
# Title is: None
# href is: difference-between-avoidable-and-unavoidable-cost
# Inner Text is: 22nd Jun - Difference Between Coordination and Cooperation
# Title is: None
# href is: difference-between-coordination-and-cooperation
# Inner Text is: 22nd Jun - Difference Between Direct and Indirect Speech
# Title is: None
# href is: difference-between-direct-and-indirect-speech
# Inner Text is: 22nd Jun - Difference Between Invoice and Receipt
# Title is: None
# href is: difference-between-invoice-and-receipt
# Inner Text is: 22nd Jun - Difference Between Predictive and Prescriptive Analytics
# Title is: None
# href is: difference-between-predictive-and-prescriptive-analytics
# Inner Text is: 22nd Jun - Difference Between Presidential and Parliamentary Democracy
# Title is: None
# href is: difference-between-presidential-and-parliamentary-democracy
# Inner Text is: 22nd Jun - Difference Between Price, Cost and Value
# Title is: None
# href is: difference-between-price-cost-and-value
# Inner Text is: 22nd Jun - Difference Between Primary Evidence and Secondary Evidence
# Title is: None
# href is: difference-between-primary-evidence-and-secondary-evidence
# Inner Text is: 22nd Jun - Difference Between Prime Cost and Conversion Cost
# Title is: None
# href is: difference-between-prime-cost-and-conversion-cost
# Inner Text is: 22nd Jun - Difference Between Quotation and Tender
# Title is: None
# href is: difference-between-quotation-and-tender
# Inner Text is: 22nd Jun - Difference Between Scholarship and Fellowship
# Title is: None
# href is: difference-between-scholarship-and-fellowship
# Inner Text is: 22nd Jun - Difference Between Validity and Reliability
# Title is: None
# href is: difference-between-validity-and-reliability
# Inner Text is: 22nd Jun - Difference Between Subungual Hematoma and Melanoma
# Title is: None
# href is: difference-between-subungual-hematoma-and-melanoma
# Inner Text is: 22nd Jun - Difference Between Social Science And Humanities
# Title is: None
# href is: difference-between-social-science-and-humanities
# Inner Text is: 22nd Jun - Difference Between Travel and Tourism
# Title is: None
# href is: difference-between-travel-and-tourism
# Inner Text is: 22nd Jun - Difference Between Value Proposition and Marketing Offer
# Title is: None
# href is: difference-between-value-proposition-and-marketing-offer
# Inner Text is: 22nd Jun - Difference Between Vowels and Consonants
# Title is: None
# href is: difference-between-vowels-and-consonants
# Inner Text is: 22nd Jun - Difference between Warm and Cool Blonde
# Title is: None
# href is: difference-between-warm-and-cool-blonde
# Inner Text is: 22nd Jun - Difference between TRAb and TSI Test
# Title is: None
# href is: difference-between-trab-and-tsi-test
# Inner Text is: 22nd Jun - Difference Between Unilateral and Bilateral Contracts
# Title is: None
# href is: difference-between-unilateral-and-bilateral-contracts
# Inner Text is: 22nd Jun - Difference Between Transitive and Intransitive Verbs
# Title is: None
# href is: difference-between-transitive-and-intransitive-verbs
# Inner Text is: 22nd Jun - Difference Between Acquittal and Discharge
# Title is: None
# href is: difference-between-acquittal-and-discharge
# Inner Text is: 22nd Jun - Difference Between Across and Through
# Title is: None
# href is: difference-between-across-and-through
# Inner Text is: 22nd Jun - Difference Between Investigation and Inquiry
# Title is: None
# href is: difference-between-investigation-and-inquiry
# Inner Text is: 22nd Jun - Difference Between Marginal Analysis and Break-even Analysis
# Title is: None
# href is: difference-between-marginal-analysis-and-break-even-analysis
# Inner Text is: 22nd Jun - Difference Between Master Budget and Cash Budget
# Title is: None
# href is: difference-between-master-budget-and-cash-budget
# Inner Text is: 22nd Jun - Difference Between Product Positioning and Brand Positioning
# Title is: None
# href is: difference-between-product-positioning-and-brand-positioning
# Inner Text is: 22nd Jun - Difference Between Monetary and Non-Monetary Asset
# Title is: None
# href is: difference-between-monetary-and-non-monetary-asset
# Inner Text is: 22nd Jun - Difference Between Social Media Marketing and Digital Marketing
# Title is: None
# href is: difference-between-social-media-marketing-and-digital-marketing
# Inner Text is: 22nd Jun - Difference Between Active and Passive Learning
# Title is: None
# href is: difference-between-active-and-passive-learning
# Inner Text is: 22nd Jun - Difference Between Active Listening and Passive Listening
# Title is: None
# href is: difference-between-active-listening-and-passive-listening
# Inner Text is: 22nd Jun - Difference Between Alliance And Coalition
# Title is: None
# href is: difference-between-alliance-and-coalition
# Inner Text is: 22nd Jun - Difference Between Physical Capital and Human Capital
# Title is: None
# href is: difference-between-physical-capital-and-human-capital
# Inner Text is: 22nd Jun - Difference Between Upselling and Cross-selling
# Title is: None
# href is: difference-between-upselling-and-cross-selling
# Inner Text is: 22nd Jun - Difference Between Unipolar and Bipolar World
# Title is: None
# href is: difference-between-unipolar-and-bipolar-world
# Inner Text is: 22nd Jun - Difference between Tax Planning and Tax Avoidance
# Title is: None
# href is: difference-between-tax-planning-and-tax-avoidance
# Inner Text is: 22nd Jun - Difference Between Peer Pressure and Peer Influence
# Title is: None
# href is: difference-between-peer-pressure-and-peer-influence
# Inner Text is: 22nd Jun - Difference Between Options and Swaps
# Title is: None
# href is: difference-between-options-and-swaps
# Inner Text is: 22nd Jun - Difference between Laws and Ethics
# Title is: None
# href is: difference-between-laws-and-ethics
# Inner Text is: 22nd Jun - Difference Between Economic and Social Infrastructure
# Title is: None
# href is: difference-between-economic-and-social-infrastructure
# Inner Text is: 22nd Jun - Difference Between Content Writing and Copy Writing
# Title is: None
# href is: difference-between-content-writing-and-copy-writing
# Inner Text is: 22nd Jun - Difference Between By Product and Waste
# Title is: None
# href is: difference-between-by-product-and-waste
# Inner Text is: 22nd Jun - Difference between Deduction and Exemption
# Title is: None
# href is: difference-between-deduction-and-exemption
# Inner Text is: 22nd Jun - Difference between Market Economy and Command Economy
# Title is: None
# href is: difference-between-market-economy-and-command-economy
# Inner Text is: 22nd Jun - Difference between Optimism and Pessimism
# Title is: None
# href is: difference-between-optimism-and-pessimism
# Inner Text is: 22nd Jun - Difference Between Article and Essay
# Title is: None
# href is: difference-between-article-and-essay
# Inner Text is: 22nd Jun - Difference Between Whole Life and Term Life Insurance
# Title is: None
# href is: difference-between-whole-life-and-term-life-insurance
# Inner Text is: 22nd Jun - Difference Between Translation and Remeasurement
# Title is: None
# href is: difference-between-translation-and-remeasurement
# Inner Text is: 22nd Jun - Difference between Orientation and Onboarding
# Title is: None
# href is: difference-between-orientation-and-onboarding
# Inner Text is: 22nd Jun - Difference between Proportionate Consolidation and Equity Method
# Title is: None
# href is: difference-between-proportionate-consolidation-and-equity-method
# Inner Text is: 22nd Jun - Difference between Hedging and Forward Contract
# Title is: None
# href is: difference-between-hedging-and-forward-contract
# Inner Text is: 22nd Jun - Difference Between Historical Cost And Fair Value
# Title is: None
# href is: difference-between-historical-cost-and-fair-value
# Inner Text is: 22nd Jun - Difference Between Line Organization And Functional Organization
# Title is: None
# href is: difference-between-line-organization-and-functional-organization
# Inner Text is: 22nd Jun - Difference Between Matrix and Functional Structure
# Title is: None
# href is: difference-between-matrix-and-functional-structure
# Inner Text is: 22nd Jun - Difference Between Rules and Norms
# Title is: None
# href is: difference-between-rules-and-norms
# Inner Text is: 22nd Jun - Difference between Rules and Standards
# Title is: None
# href is: difference-between-rules-and-standards
# Inner Text is: 22nd Jun - Difference Between Servant Leadership and Transformational Leadership
# Title is: None
# href is: difference-between-servant-leadership-and-transformational-leadership
# Inner Text is: 22nd Jun - Difference between Tax Deduction and Tax Credits
# Title is: None
# href is: difference-between-tax-deduction-and-tax-credits
# Inner Text is: 22nd Jun - Difference Between Present Value And Net Present Value
# Title is: None
# href is: difference-between-present-value-and-net-present-value
# Inner Text is: 22nd Jun - MongoDB vs NoSQL
# Title is: None
# href is: mongodb-vs-nosql
# Inner Text is: 22nd Jun - Oracle vs SQL
# Title is: None
# href is: oracle-vs-sql
# Inner Text is: 22nd Jun - Difference Between Airedale And Welsh Terrier
# Title is: None
# href is: difference-between-airedale-and-welsh-terrier
# Inner Text is: 22nd Jun - Difference Between Annuity and Perpetuity
# Title is: None
# href is: difference-between-annuity-and-perpetuity
# Inner Text is: 22nd Jun - Difference Between APR and Note Rate
# Title is: None
# href is: difference-between-apr-and-note-rate
# Inner Text is: 22nd Jun - Difference Between Bloating and Distension
# Title is: None
# href is: difference-between-bloating-and-distension
# Inner Text is: 22nd Jun - Difference Between Consumer Market and Business Market
# Title is: None
# href is: difference-between-consumer-market-and-business-market
# Inner Text is: 22nd Jun - Difference Between EVA And ROI
# Title is: None
# href is: difference-between-eva-and-roi
# Inner Text is: 22nd Jun - Difference Between Functional and Divisional Structure
# Title is: None
# href is: difference-between-functional-and-divisional-structure
# Inner Text is:
# Title is: None
# href is: https://feeds.feedburner.com/javatpointsonoo
# Inner Text is:
# Title is: None
# href is: https://feedburner.google.com/fb/a/mailverify?uri=javatpointsonoo
# Inner Text is:
# Title is: None
# href is: https://www.facebook.com/javatpoint
# Inner Text is:
# Title is: None
# href is: https://twitter.com/pagejavatpoint
# Inner Text is:
# Title is: None
# href is: https://www.youtube.com/channel/UCUnYvQVCrJoFWZhKK3O2xLg
# Inner Text is:
# Title is: None
# href is: https://javatpoint.blogspot.com
# Inner Text is: Learn Java
# Title is: None
# href is: https://www.javatpoint.com/java-tutorial
# Inner Text is: Learn Data Structures
# Title is: None
# href is: https://www.javatpoint.com/data-structure-tutorial
# Inner Text is: Learn C Programming
# Title is: None
# href is: https://www.javatpoint.com/c-programming-language-tutorial
# Inner Text is: Learn C++ Tutorial
# Title is: None
# href is: https://www.javatpoint.com/cpp-tutorial
# Inner Text is: Learn C# Tutorial
# Title is: None
# href is: https://www.javatpoint.com/c-sharp-tutorial
# Inner Text is: Learn PHP Tutorial
# Title is: None
# href is: https://www.javatpoint.com/php-tutorial
# Inner Text is: Learn HTML Tutorial
# Title is: None
# href is: https://www.javatpoint.com/html-tutorial
# Inner Text is: Learn JavaScript Tutorial
# Title is: None
# href is: https://www.javatpoint.com/javascript-tutorial
# Inner Text is: Learn jQuery Tutorial
# Title is: None
# href is: https://www.javatpoint.com/jquery-tutorial
# Inner Text is: Learn Spring Tutorial
# Title is: None
# href is: https://www.javatpoint.com/spring-tutorial
# Inner Text is: Java Interview Questions
# Title is: None
# href is: corejava-interview-questions
# Inner Text is: SQL Interview Questions
# Title is: None
# href is: sql-interview-questions
# Inner Text is: Python Interview Questions
# Title is: None
# href is: python-interview-questions
# Inner Text is: JavaScript Interview Questions
# Title is: None
# href is: javascript-interview-questions
# Inner Text is: Angular Interview Questions
# Title is: None
# href is: top-angular-interview-questions
# Inner Text is: Selenium Interview Questions
# Title is: None
# href is: selenium-interview-questions
# Inner Text is: Spring Boot Interview Questions
# Title is: None
# href is: spring-boot-interview-questions
# Inner Text is: HR Interview Questions
# Title is: None
# href is: job-interview-questions
# Inner Text is: C++ Interview Questions
# Title is: None
# href is: cpp-interview-questions
# Inner Text is: Data Structure Interview Questions
# Title is: None
# href is: data-structure-interview-questions
# Inner Text is: Contact Us
# Title is: None
# href is: https://www.javatpoint.com/contact-us
# Inner Text is: Privacy Policy
# Title is: None
# href is: https://www.javatpoint.com/privacy-policy
# Inner Text is: Sitemap
# Title is: None
# href is: https://www.javatpoint.com/sitemap.xml
# Inner Text is: About Me
# Title is: None
# href is: https://www.javatpoint.com/sonoo-jaiswal
